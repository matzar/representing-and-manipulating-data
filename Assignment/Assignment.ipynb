# %% [markdown]
#  # University of Stirling
#
#  # ITNPBD2, Representing and Manipulating Data
#
#  # Assignment 2019
#
#  # An analysis of the book, Around the World in 80 Days by Jules Verne
#
#  This notebook forms the assignment instructions and submission document of the assignment for ITNPBD2 in 2019. Read the instructions carefully and enter code into the cells as indicated.
#
#  You will need to download the text of the book from Canvas - it is in the same place as this file, and called aroundTW80Days.txt.
#
#  Rename this file to be xxxxxx_BD2 where xxxxxx is your student number, then type your code into the boxes provided. Each question is given in a markdown call, and there is an empty box beneath each one where you enter your answer. These boxes should contain 2 things:
#
#  - **The code that performs the required task**
#  - **Comments that explain your code**
#
#  Marks are given for both code (70%) and style and comments (30%). If you cannot get the code to work properly, you will still get some marks for correct comments. The marks available for each question are given in square brackets in each title.

# %% [markdown]
#  # Submission and Other Notes
#
#  - Submit your notebook to canvas when it is complete
#  - Make sure the version you submit contains the results of running every cell. The output should be visible without the need to run the code again
#
#  ## Plagiarism
#
#  Plagiarism is presenting somebody else’s work as your own. Plagiarism is a form of academic misconduct and is taken very seriously by the University. Students found to have plagiarised work can have marks deducted and, in serious cases, even be expelled from the University. Do not submit any work that is not entirely your own.
#
#  The University’s full guidance on academic misconduct can be found here:
#
#  http://stir.ac.uk/1x0

# %% [markdown]
#  ## 1) Open the file `aroundTW80Days.txt` and read its contents into a string [3]
#
#
#  1. Print the number of characters (letters, etc) in the whole book
#  2. Split the book into a Python list containing all the words of the book in order. At this stage, use string splitting, not a more fancy library like `nltk`. Call this variable `book_list`
#  3. Print the number of words in the book
#  4. Print the first 10 words of the book. It should look like this:
#
#  `['The', 'Project', 'Gutenberg', 'EBook', 'of', 'Around', 'the', 'World', 'in', '80', 'Days,']`

# %%
import random
import string
import re

# Answer 1
# read the book into a string, use 'r' to prevent reading of special characters in the file name
# and replace new line ('\n') characters with a white space
data = open(r"aroundTW80Days.txt", "r").read().replace('\n',' ')

# Clean the data
# Split the book into words
book_words = data.split()

# create new list, from book_list, with no punctuation, called book_no_punc
book_no_punc = list()
for word in book_words:
    book_no_punc.append(word.strip(string.punctuation))

# 1. Number of characters in the book
print("Number of characters in the book:", len(data))
# 2. Split the book into a sorted list
book_list = sorted(list(book_words))
rnd = random.randint(100, 109)
print("Random sample from the sorted book:", book_list[rnd:rnd+5])
# 3. Number of words in the book
print("Number of words in the book:", len(book_words))
# 4. The first 10 words of the book
print("The first 10 words from the book:", book_words[0:10])
# Out:
# Number of characters in the book: 390222
# Random sample from the sorted book: ['"Are', '"Are', '"Are', '"Arrived', '"As']
# Number of words in the book: 66313
# The first 10 words from the book: ['The', 'Project', 'Gutenberg', 'EBook', 'of', 'Around', 'the', 'World', 'in', '80']

# %% [markdown]
#  ## 2) Now create a set containing all the unique words in the book [3]
#  - Print the number of unique words it finds

# %%
# Answer 2
# Set stores values only once, so we're going to convert the list containing
# all the words in the book into a set, hence getting all the unique words
# but first we need to get rid of all the punctuation signs so we don't 
# count, e.g., "Francisco?" and "Francisco" as two unique words

book_no_punc = list()
# create new list, from book_list, with no punctuation, called book_no_punc
for word in book_words:
    book_no_punc.append(word.strip(string.punctuation))

# convert book_unique list into a set to obtain the unique values
book_unique = set(book_no_punc)
print(book_unique)
# Out:
# {'', 'despite', 'WORLD', 'air', 'services', 'persuading', 'district', 'trifle', 'four', 'UNKNOWN', 'creek', 'donation', 'XXX', 'Have', 'profits', 'Club', 'fruit', 'Gutenberg-tm', 'sheltered', 'Point', 'crowds', 'puts', 'shall', 'palings', 'coolly', 'devoured', 'crown', 'Glad', 'employees', 'retreat', 'telescopes', 'rid', 'MAKING', 'Chance', 'mechanics', 'afraid', 'dividing', 'quarters', 'still', 'cherry', 'variety', 'daybreak', 'reckon', 'forged', "Fallentin's", 'swan-skin', 'millions', 'saw', 'rapid', 'rogues', 'CERTAIN', 'masterpieces', 'ferryboat', 'refreshment-rooms', 'other', 'today', 'match', 'Jordan', 'bound', 'anew', 'lodged', 'thicket', 'Ceylon', 'Kandallah', 'replied', 'growing', 'checking', 'possessions', 'gilded', 'covering', 'Buddhist', 'pair', 'commanding', 'pilot-boat--No', 'Southampton', 'foolish', 'walked', 're-embarked', 'animal', 'occasioned', 'Pere', 'shaved', 'peristyles', 'youth', 'fifty', 'warned', 'south-easterly', 'banker', 'IRS', 'tolerate', 'link', "let's", 'divan', 'EBook', 'south-eastward', 'resistance', 'modification', 'expressed', 'passions', 'side-walks', 'mystery', 'violated', 'authority', 'meditation', 'submit', 'strolling', 'periodic', 'avoid', 'Ghazipur', "we've", 'colour', 'notice', 'whist', 'forbidden', 'embroidered', 'larger', 'bolder', 'most', 'less', 'imaginable', 'swore', 'little', 'clove-trees', 'splendid', 'sternly', 'alarmed', 'XXXVI', 'consumed', 'favour', 'packages', 'unaffected', 'PLACE', 'corporation', 'him--begged', 'eccentric', 'beast--could', 'Paris', 'divulge', 'object', 'decamped', 'oaths', 'halted', 'Presidency', 'request', 'suttee', 'whist-table', 'IN', 'Northern', 'abridged', 'seeing', 'infected', 'satisfy', 'loveliest', 'debtor', 'cravat', 'ACTUAL', 'lies', 'preserve', 'quite', 'whistling', 'Gone', 'pagoda', 'curves', 'admiringly', 'conviction', 'registered', 'delicate', 'thirty-three', 'now', 'self-composed', 'Juggernaut', 'occurrences', 'date', 'bathed', 'courageous', 'killed', 'well-arranged', 'advance', 'soul', 'Strand', 'Deal', 'strong', 'borne', 'ridge', 're-appeared', 'people', 'personage', 'implicated', 'Agra', 'equally', 'hilly', 'restored', 'swept', 'month', 'paralytic', 'saucer', 'mosaic', 'Captain', 'disconnected', 'automaton', 'suspended', 'concocted', 'cultivate', 'Southern', 'reef', 'feel', 'tower', "snail's", 'coal', 'XXII', 'arsenal', 'big', 'cannibals', 'Confound', 'INDEMNITY', 'horrible', 'Treaty', 'forty-second', 'in', '1.E', 'morning', 'islands', 'farthing', 'DISTRIBUTOR', 'typhoon', 'Fo-Kien', 'Do', 'minarets', 'encamped', 'blundering', 'tickets', 'Pacific', 'Without', "That's", 'Sioux', 'twisted', 'awaiting', 'Messrs', 'eBook', 'hearts', 'regain', 'rhubarb', 'usually', 'accepting', 'methodical', 'sequel', 'hidden', 'turnings', 'TALKS', 'totter', 'saki', 'guidance', 'depot', 'half-mast', 'marched', 'cathedral', 'Mr.--Mr', 'sauntering', 'Saddle', 'gale', 'gentlemen', 'groin', 'projects', 'Pole', 'Apiece', "workmen's", 'station-master', 'cup', 'neighbour', 'contrasted', 'cherished', 'antagonists', 'do', 'HISTORY', 'him--not', 'Gothic', 'poles', 'annoyance', "desecrator's", 'attempts', 'sharing', 'vast', 'sway', 'guests', 'leaning', 'ninety-nine', 'restoration', 'Carnival', 'clogs', 'right-angles', 'circumference', 'moustache', 'certain', 'haggard', 'tribe', 'tastes', 'mean', 'putting', 'honourable', 'attract', 'streams', 'jumping', 'postpone', 'MR', 'muttered', 'Mormons', 'employment', 'coast', 'reveries', 'Land', 'Cani', 'anger', 'announce', 'empty', 'hundred', 'dressing', 'slender', 'gunshots', 'multitudes', 'palatable', 'desirous', 'fireplace', 'rate', 'heinous', '1.F.4', 'warmly', 'average', 'execution', 'breakage', 'Sandy', 'tide', 'notifies', '99712', 'sell', '2008', 'bushes', 'brown', 'fat', 'seventeen', 'WILLIAM', 'SEEING', 'heartless', 'persecutions', 'twentieth', 'injuries', 'swarming', 'cloud', 'guess', 'breakfasted', 'calculating', 'minimum', 'legendary', 'Stephenson', 'porches', 'enterprise', 'promptly', 'theatre', 'fist', 'pierce', 'but ...

# %% [markdown]
#  ## 3) Build a Dictionary of the words used in the book [3]
#  - Build a Python dictionary (`dict`) in which the keys are the unique words in the book and the values are dictionary objects with fields `length` for word length and `freq` for frequency, e.g.:
#
#  `{'the': {'length': 3, 'freq': 4303}}`

# %%
# Answer 3 
book_dict = dict()

# !!! WARNING !!! - long execution! Only use if you need the whole dictionary in the memory, otherwise
# use the generator version instead

# create a dictionary of words with words as the key and a tuple with its length and frequency
for word in book_no_punc:
    book_dict.update({word: (len(word), book_no_punc.count(word))})
# print(book_dict)

# %%
# generator version of the same dictionary
gen_book_dic = (book_dict.update({word: (len(word), book_no_punc.count(word))}) for word in book_no_punc)
# print(gen_book_dic)

# %% [markdown]
#  ## 4) Use the dictionary that you created above to find the most commonly used word in the book [3]
#  - Print the word and the number of times it appeared in the book

# %%
# Answer 4
# We're using the book_no_punc list because we don't want to count
# "Francisco?" and "Francisco" twice and get two unique keys and values
print(max(book_no_punc, key=lambda x: book_no_punc[1]))
# Out:
# The

# %% [markdown]
#  ## 5) Write a generator function to produce each word and its length each time it yields a value [6]
#
#  - The function should accept a single argument: the list of words in the book
#  - It should yield a tuple (word, word_len)
#  - Call the function to create a generator but do not iterate over it at this stage

# %%
# Answer 5
# generator expression which yields a tuple of a word and its length
wordLenghtGenerator = ((word, len(word)) for word in book_no_punc)

# %% [markdown]
#  ## 6) Use a comprehension over the generator you just made to list all the words with 9 letters [6]
#
#  - Print all those words
#  - Extra points if each word is selected only once

# %%
# Answer 6

# generator expression which yields a tuple of a word of length 9 and its length, which is 9
wordLenghtGenerator = ((word, len(word)) for word in book_no_punc if len(word) == 9)

# printing words of lenght 9 using the generator expression
for word in wordLenghtGenerator:
    print(word)

# printing words of lenght 9 only once using the generator expression
seen_before = list()

for word in wordLenghtGenerator:
    if word not in seen_before:
        seen_before.append(word)

for word in seen_before:
    print(word)

# display(seen_before)
# Out:
# ('Gutenberg', 9)
# ('Gutenberg', 9)
# ('GUTENBERG', 9)
# ('CONVINCED', 9)
# ('DETECTIVE', 9)
# ('PASSPORTS', 9)
# ('BEAUTIFUL', 9)
# ('BANKNOTES', 9)
# ('DISGORGES', 9)
# ('THOUSANDS', 9)
# ('SINGAPORE', 9)
# ('TANKADERE', 9)
# ('ANTIPODES', 9)
# ('FRANCISCO', 9)
# ('UNDERGOES', 9)
# ('INCIDENTS', 9)
# ('RAILROADS', 9)
# ('DETECTIVE', 9)
# ('INTERESTS', 9)
# ('HAPPINESS', 9)
# ('attention', 9)
# ('personage', 9)
# ('resembled', 9)
# ('Byron--at', 9)
# ('Certainly', 9)
# ("Lincoln's", 9)
# ('resounded', 9)
# ('Exchequer', 9)
# ('certainly', 9)
# ('gentleman', 9)
# ('societies', 9)
# ("Artisan's", 9)
# ('societies', 9)
# ('admission', 9)
# ('exclusive', 9)
# ('regularly', 9)
# ('sometimes', 9)
# ('travelled', 9)
# ('corrected', 9)
# ('travelled', 9)
# ('charities', 9)
# ('congenial', 9)
# ('relatives', 9)
# ('certainly', 9)
# ('supported', 9)
# ('illumined', 9)
# ('resources', 9)
# ('club--its', 9)
# ('succulent', 9)
# ('swan-skin', 9)
# ('proffered', 9)
# ('porcelain', 9)
# ('decanters', 9)
# ('contained', 9)
# ('beverages', 9)
# ('eccentric', 9)
# ('confessed', 9)
# ('something', 9)
# ('sumptuous', 9)
# ('dismissed', 9)
# ('successor', 9)
# ('half-past', 9)
# ('grenadier', 9)
# ('indicated', 9)
# ('half-past', 9)
# ('according', 9)
# ('apartment', 9)
# ('dismissed', 9)
# ('Frenchman', 9)
# ('outspoken', 9)
# ('itinerant', 9)
# ('professor', 9)
# ('gentleman', 9)
# ('responded', 9)
# ('Wednesday', 9)
# ('automatic', 9)
# ('departing', 9)
# ('CONVINCED', 9)
# ("Tussaud's", 9)
# ("Tussaud's", 9)
# ('interview', 9)
# ('carefully', 9)
# ('observing', 9)
# ('possessed', 9)
# ('composure', 9)
# ('Kauffmann', 9)
# ('skilfully', 9)
# ('perfectly', 9)
# ('regulated', 9)
# ('abandoned', 9)
# ('shoulders', 9)
# ('developed', 9)
# ('exercises', 9)
# ('sculptors', 9)
# ('arranging', 9)
# ("Minerva's", 9)
# ('completed', 9)
# ('whimsical', 9)
# ('irregular', 9)
# ('adventure', 9)
# ('Longferry', 9)
# ('Haymarket', 9)
# ('shoulders', 9)
# ('gentleman', 9)
# ('travelled', 9)
# ('overnight', 9)
# ('presented', 9)
# ('half-past', 9)
# ('satisfied', 9)
# ('precisely', 9)
# ('programme', 9)
# ('comprised', 9)
# ('half-past', 9)
# ('Club--all', 9)
# ('regulated', 9)
# ('half-past', 9)
# ('gentleman', 9)
# ('idealised', 9)
# ('libraries', 9)
# ('peaceable', 9)
# ('gentleman', 9)
# ('half-past', 9)
# ('colouring', 9)
# ('breakfast', 9)
# ('consisted', 9)
# ('side-dish', 9)
# ('garnished', 9)
# ('mushrooms', 9)
# ('sumptuous', 9)
# ('apartment', 9)
# ('paintings', 9)
# ('proceeded', 9)
# ('operation', 9)
# ('breakfast', 9)
# ('fireplace', 9)
# ('Fallentin', 9)
# ('Directors', 9)
# ('comprises', 9)
# ('principal', 9)
# ('Continent', 9)
# ('Telegraph', 9)
# ('gentleman', 9)
# ('banknotes', 9)
# ('principal', 9)
# ("cashier's", 9)
# ('shillings', 9)
# ('treasures', 9)
# ('banknotes', 9)
# ('curiosity', 9)
# ('neighbour', 9)
# ('Meanwhile', 9)
# ('ponderous', 9)
# ('Liverpool', 9)
# ('proffered', 9)
# ('recovered', 9)
# ('supposing', 9)
# ('Telegraph', 9)
# ('gentleman', 9)
# ('committed', 9)
# ('officials', 9)
# ('stimulate', 9)
# ('continued', 9)
# ('Fallentin', 9)
# ('proceeded', 9)
# ('excepting', 9)
# ('Certainly', 9)
# ('convinced', 9)
# ('gentlemen', 9)
# ('Allahabad', 9)
# ('Peninsula', 9)
# ('Telegraph', 9)
# ('Francisco', 9)
# ('Francisco', 9)
# ('exclaimed', 9)
# ('accidents', 9)
# ('beginning', 9)
# ('Fallentin', 9)
# ('continued', 9)
# ('willingly', 9)
# ('well-used', 9)
# ('Fallentin', 9)
# ('consulted', 9)
# ('Wednesday', 9)
# ('deposited', 9)
# ('gentlemen', 9)
# ('preserved', 9)
# ('composure', 9)
# ('certainly', 9)
# ('difficult', 9)
# ('difficult', 9)
# ('departure', 9)
# ('gentlemen', 9)
# ('programme', 9)
# ('surprised', 9)
# ('appearing', 9)
# ('according', 9)
# ('precisely', 9)
# ('responded', 9)
# ('stupefied', 9)
# ('responded', 9)
# ('stockings', 9)
# ('departure', 9)
# ('gentleman', 9)
# ('wardrobes', 9)
# ('carefully', 9)
# ('descended', 9)
# ('red-bound', 9)
# ('departure', 9)
# ('forgotten', 9)
# ('descended', 9)
# ('shoulders', 9)
# ('sensation', 9)
# ('purchased', 9)
# ('perceived', 9)
# ('gentlemen', 9)
# ('gentleman', 9)
# ('gentlemen', 9)
# ('ensconced', 9)
# ('recovered', 9)
# ('suspected', 9)
# ('departure', 9)
# ('sensation', 9)
# ('Telegraph', 9)
# ('supported', 9)
# ('geography', 9)
# ('Telegraph', 9)
# ('agreement', 9)
# ('departure', 9)
# ('necessary', 9)
# ('distances', 9)
# ('misgiving', 9)
# ('accidents', 9)
# ('machinery', 9)
# ('liability', 9)
# ('seriously', 9)
# ('depressed', 9)
# ('advocates', 9)
# ('Everybody', 9)
# ('Albemarle', 9)
# ('paralytic', 9)
# ('gentleman', 9)
# ('adventure', 9)
# ('contented', 9)
# ('everybody', 9)
# ('departure', 9)
# ('following', 9)
# ('Detective', 9)
# ('gentleman', 9)
# ('departure', 9)
# ('DETECTIVE', 9)
# ('belonging', 9)
# ('Wednesday', 9)
# ('regularly', 9)
# ('belonging', 9)
# ('strangers', 9)
# ('personage', 9)
# ('twitching', 9)
# ('nervously', 9)
# ('passenger', 9)
# ('detective', 9)
# ('evidently', 9)
# ('obtaining', 9)
# ('twentieth', 9)
# ('yesterday', 9)
# ("company's", 9)
# ('recognise', 9)
# ('gentlemen', 9)
# ('windfalls', 9)
# ('shillings', 9)
# ('detective', 9)
# ('otherwise', 9)
# ('evidently', 9)
# ('merchants', 9)
# ('roadstead', 9)
# ('retaining', 9)
# ('fantastic', 9)
# ('according', 9)
# ('half-past', 9)
# ('exclaimed', 9)
# ('companion', 9)
# ('concealed', 9)
# ('furnished', 9)
# ('detective', 9)
# ('meanwhile', 9)
# ('impatient', 9)
# ('intending', 9)
# ('naturally', 9)
# ('difficult', 9)
# ('announced', 9)
# ('carefully', 9)
# ('Presently', 9)
# ('consulate', 9)
# ('identical', 9)
# ('establish', 9)
# ('necessary', 9)
# ('consulate', 9)
# ('disturbed', 9)
# ('passenger', 9)
# ('PASSPORTS', 9)
# ('detective', 9)
# ('believing', 9)
# ('passenger', 9)
# ('Passports', 9)
# ('strangers', 9)
# ('carefully', 9)
# ('Frenchman', 9)
# ('proceeded', 9)
# ('customary', 9)
# ('detective', 9)
# ('perfectly', 9)
# ('gentleman', 9)
# ('resembles', 9)
# ('Frenchman', 9)
# ('Meanwhile', 9)
# ('consulate', 9)
# ('descended', 9)
# ('note-book', 9)
# ('contained', 9)
# ('following', 9)
# ('memoranda', 9)
# ('Wednesday', 9)
# ('Wednesday', 9)
# ('inscribed', 9)
# ('itinerary', 9)
# ('principal', 9)
# ('Singapore', 9)
# ('Francisco', 9)
# ('contained', 9)
# ('breakfast', 9)
# ('countries', 9)
# ('domestics', 9)
# ('detective', 9)
# ('responded', 9)
# ('Certainly', 9)
# ('excellent', 9)
# ('exclaimed', 9)
# ('something', 9)
# ('character', 9)
# ('banknotes', 9)
# ('detective', 9)
# ('departure', 9)
# ('eagerness', 9)
# ('countries', 9)
# ('eccentric', 9)
# ('foolhardy', 9)
# ('confirmed', 9)
# ('continued', 9)
# ('existence', 9)
# ('Certainly', 9)
# ('shillings', 9)
# ('attention', 9)
# ('listening', 9)
# ('companion', 9)
# ('purchases', 9)
# ('consulate', 9)
# ('convinced', 9)
# ('recovered', 9)
# ('returning', 9)
# ('countries', 9)
# ('important', 9)
# ('instantly', 9)
# ('detective', 9)
# ('telegraph', 9)
# ('precisely', 9)
# ('exertions', 9)
# ('peninsula', 9)
# ('officials', 9)
# ('receiving', 9)
# ('divisions', 9)
# ('breakfast', 9)
# ('fearfully', 9)
# ('interrupt', 9)
# ('unvarying', 9)
# ('curiosity', 9)
# ('memorable', 9)
# ('recognise', 9)
# ('eccentric', 9)
# ('personage', 9)
# ('returning', 9)
# ('absorbing', 9)
# ('gentleman', 9)
# ('recognise', 9)
# ('elephants', 9)
# ('curiosity', 9)
# ('pretended', 9)
# ('Meanwhile', 9)
# ('mountains', 9)
# ('following', 9)
# ('distances', 9)
# ('programme', 9)
# ('according', 9)
# ('sauntered', 9)
# ('Europeans', 9)
# ('Gibraltar', 9)
# ('engineers', 9)
# ('engineers', 9)
# ('returning', 9)
# ('something', 9)
# ('roadstead', 9)
# ('enchanted', 9)
# ('congenial', 9)
# ('companion', 9)
# ('half-past', 9)
# ('finishing', 9)
# ('concluded', 9)
# ('brilliant', 9)
# ('departure', 9)
# ('itinerary', 9)
# ('Everybody', 9)
# ('unequally', 9)
# ('exercises', 9)
# ('stationed', 9)
# ('governors', 9)
# ('authority', 9)
# ('ferocious', 9)
# ('gradually', 9)
# ('appointed', 9)
# ('horseback', 9)
# ('traverses', 9)
# ('peninsula', 9)
# ('Peninsula', 9)
# ('continent', 9)
# ('territory', 9)
# ('Allahabad', 9)
# ('half-past', 9)
# ('polygonal', 9)
# ('Elephanta', 9)
# ('concealed', 9)
# ('Kanherian', 9)
# ('palatable', 9)
# ('continued', 9)
# ('detective', 9)
# ('nervously', 9)
# ('concerned', 9)
# ('important', 9)
# ('purchased', 9)
# ('leisurely', 9)
# ('promenade', 9)
# ('collected', 9)
# ('civilised', 9)
# ('merchants', 9)
# ('religious', 9)
# ('Unhappily', 9)
# ('curiosity', 9)
# ('forbidden', 9)
# ('disregard', 9)
# ('practices', 9)
# ('religions', 9)
# ('sprawling', 9)
# ('forthwith', 9)
# ('Frenchman', 9)
# ('necessary', 9)
# ('detective', 9)
# ('committed', 9)
# ('officials', 9)
# ('merchants', 9)
# ('passenger', 9)
# ('intervals', 9)
# ('character', 9)
# ('according', 9)
# ('mechanics', 9)
# ('departure', 9)
# ('eccentric', 9)
# ('concealed', 9)
# ('gentleman', 9)
# ('Kandallah', 9)
# ('mountains', 9)
# ('exchanged', 9)
# ('mountains', 9)
# ('Kandallah', 9)
# ('obstacles', 9)
# ('adventure', 9)
# ('religious', 9)
# ('respected', 9)
# ('condemned', 9)
# ('mountains', 9)
# ('proceeded', 9)
# ('Khandeish', 9)
# ('territory', 9)
# ('bungalows', 9)
# ('abandoned', 9)
# ('extending', 9)
# ('inhabited', 9)
# ('succeeded', 9)
# ('elephants', 9)
# ('Milligaum', 9)
# ('sectaries', 9)
# ('ferocious', 9)
# ('provinces', 9)
# ('Feringhea', 9)
# ('strangled', 9)
# ('travelled', 9)
# ('direction', 9)
# ('succeeded', 9)
# ('half-past', 9)
# ('proceeded', 9)
# ('breakfast', 9)
# ('Assurghur', 9)
# ('absorbing', 9)
# ('fantastic', 9)
# ('therefore', 9)
# ('necessity', 9)
# ('accidents', 9)
# ('Mountains', 9)
# ('Khandeish', 9)
# ('timepiece', 9)
# ('regulated', 9)
# ('Greenwich', 9)
# ('corrected', 9)
# ('whereupon', 9)
# ('insisting', 9)
# ('regulated', 9)
# ('therefore', 9)
# ('bungalows', 9)
# ("workmen's", 9)
# ('conductor', 9)
# ('carriages', 9)
# ('surprised', 9)
# ('proceeded', 9)
# ('conductor', 9)
# ('Certainly', 9)
# ('Allahabad', 9)
# ('announced', 9)
# ('conductor', 9)
# ('Allahabad', 9)
# ('willingly', 9)
# ('conductor', 9)
# ('Allahabad', 9)
# ('therefore', 9)
# ('sacrifice', 9)
# ('confident', 9)
# ('premature', 9)
# ('carriages', 9)
# ('searching', 9)
# ('conducted', 9)
# ('enclosure', 9)
# ('elephants', 9)
# ('direction', 9)
# ('preserved', 9)
# ('doubtless', 9)
# ('elephants', 9)
# ('therefore', 9)
# ('persisted', 9)
# ('excessive', 9)
# ('Allahabad', 9)
# ('supposing', 9)
# ('Allahabad', 9)
# ('gentleman', 9)
# ('necessary', 9)
# ('Returning', 9)
# ('promising', 9)
# ('stimulate', 9)
# ('curiously', 9)
# ('banknotes', 9)
# ('extracted', 9)
# ('Allahabad', 9)
# ('brigadier', 9)
# ('traveller', 9)
# ('purchased', 9)
# ('Mountains', 9)
# ('otherwise', 9)
# ('quenching', 9)
# ('devouring', 9)
# ('regretted', 9)
# ('descended', 9)
# ('exclaimed', 9)
# ('preparing', 9)
# ('breakfast', 9)
# ('departure', 9)
# ('presented', 9)
# ('succeeded', 9)
# ('inhabited', 9)
# ('fanatical', 9)
# ('practices', 9)
# ('territory', 9)
# ('subjected', 9)
# ('influence', 9)
# ('ferocious', 9)
# ('perceived', 9)
# ('convulsed', 9)
# ('Allahabad', 9)
# ('ruinously', 9)
# ('expensive', 9)
# ('estimable', 9)
# ('certainly', 9)
# ('principal', 9)
# ('separated', 9)
# ('Allahabad', 9)
# ('purchased', 9)
# ('beginning', 9)
# ('occupants', 9)
# ('slumbered', 9)
# ('Allahabad', 9)
# ('beginning', 9)
# ('descended', 9)
# ('Kallenger', 9)
# ('inhabited', 9)
# ('Allahabad', 9)
# ('succulent', 9)
# ('preferred', 9)
# ('listening', 9)
# ('patiently', 9)
# ('necessary', 9)
# ('evidently', 9)
# ('concealed', 9)
# ('performed', 9)
# ('religious', 9)
# ('intervals', 9)
# ('prostrate', 9)
# ('whispered', 9)
# ('shoulders', 9)
# ('bracelets', 9)
# ('presented', 9)
# ('palanquin', 9)
# ('musicians', 9)
# ('rearguard', 9)
# ('sometimes', 9)
# ('gradually', 9)
# ('sacrifice', 9)
# ('voluntary', 9)
# ('to-morrow', 9)
# ('betraying', 9)
# ('barbarous', 9)
# ('incessant', 9)
# ('exclaimed', 9)
# ('treatment', 9)
# ('relatives', 9)
# ('allowance', 9)
# ('frightful', 9)
# ('existence', 9)
# ('creatures', 9)
# ('sacrifice', 9)
# ('religious', 9)
# ('Sometimes', 9)
# ('sacrifice', 9)
# ('voluntary', 9)
# ("husband's", 9)
# ('sacrifice', 9)
# ('to-morrow', 9)
# ('voluntary', 9)
# ('Everybody', 9)
# ('sacrifice', 9)
# ('To-morrow', 9)
# ('Sometimes', 9)
# ('therefore', 9)
# ('perceived', 9)
# ('necessary', 9)
# ('Excellent', 9)
# ('education', 9)
# ('relatives', 9)
# ('sacrifice', 9)
# ('narrative', 9)
# ('confirmed', 9)
# ('concealed', 9)
# ('discussed', 9)
# ('abduction', 9)
# ('perceived', 9)
# ('deepening', 9)
# ('whispered', 9)
# ('murmuring', 9)
# ('convinced', 9)
# ('attempted', 9)
# ('direction', 9)
# ('whispered', 9)
# ('brigadier', 9)
# ('ascertain', 9)
# ('announced', 9)
# ('half-past', 9)
# ('instantly', 9)
# ('awkwardly', 9)
# ('installed', 9)
# ('readiness', 9)
# ('difficult', 9)
# ('betraying', 9)
# ('whispered', 9)
# ('Allahabad', 9)
# ('sacrifice', 9)
# ('consented', 9)
# ('Meanwhile', 9)
# ('resolving', 9)
# ('commenced', 9)
# ('announced', 9)
# ('multitude', 9)
# ('sacrifice', 9)
# ("Francis's", 9)
# ('religious', 9)
# ('senseless', 9)
# ('stretched', 9)
# ("husband's", 9)
# ('instantly', 9)
# ('multitude', 9)
# ('descended', 9)
# ('inanimate', 9)
# ('supported', 9)
# ('stupefied', 9)
# ('profiting', 9)
# ('delivered', 9)
# ('recovered', 9)
# ('perceived', 9)
# ('abduction', 9)
# ('fugitives', 9)
# ('increased', 9)
# ('BEAUTIFUL', 9)
# ('venerable', 9)
# ('advancing', 9)
# ('stupefied', 9)
# ('reassured', 9)
# ('disturbed', 9)
# ('scattered', 9)
# ('Allahabad', 9)
# ('unlimited', 9)
# ('forthwith', 9)
# ('Allahabad', 9)
# ('venerated', 9)
# ('peninsula', 9)
# ('according', 9)
# ('purchases', 9)
# ('purchased', 9)
# ('influence', 9)
# ('subjected', 9)
# ('gradually', 9)
# ('poet-king', 9)
# ('brilliant', 9)
# ('freshness', 9)
# ('celestial', 9)
# ('vermilion', 9)
# ('lotus-bud', 9)
# ('loveliest', 9)
# ('treasures', 9)
# ('Allahabad', 9)
# ('proceeded', 9)
# ('adventure', 9)
# ('vengeance', 9)
# ('purchased', 9)
# ('glistened', 9)
# ('exclaimed', 9)
# ('installed', 9)
# ('recovered', 9)
# ('strangers', 9)
# ('hesitated', 9)
# ('repeating', 9)
# ('gratitude', 9)
# ('sacrifice', 9)
# ('shuddered', 9)
# ('principal', 9)
# ('merchants', 9)
# ('half-past', 9)
# ("Mahomet's", 9)
# ('suspended', 9)
# ('rejoining', 9)
# ('northward', 9)
# ('landscape', 9)
# ('mountains', 9)
# ('Elephants', 9)
# ('ablutions', 9)
# ('bitterest', 9)
# ('whistling', 9)
# ('concealed', 9)
# ('factories', 9)
# ('fortified', 9)
# ('principal', 9)
# ('foundries', 9)
# ('factories', 9)
# ("country's", 9)
# ('According', 9)
# ('therefore', 9)
# ('regretted', 9)
# ('BANKNOTES', 9)
# ('DISGORGES', 9)
# ('THOUSANDS', 9)
# ('companion', 9)
# ('unwilling', 9)
# ('dangerous', 9)
# ('policeman', 9)
# ('policeman', 9)
# ('policeman', 9)
# ('policeman', 9)
# ('policeman', 9)
# ('conducted', 9)
# ('miserable', 9)
# ('presented', 9)
# ('bristling', 9)
# ('elegantly', 9)
# ('equipages', 9)
# ('policeman', 9)
# ('requested', 9)
# ('conducted', 9)
# ('half-past', 9)
# ('prisoners', 9)
# ('exclaimed', 9)
# ('treatment', 9)
# ('contented', 9)
# ('nervously', 9)
# ('muttering', 9)
# ('reassured', 9)
# ('half-past', 9)
# ('policeman', 9)
# ('adjoining', 9)
# ('evidently', 9)
# ('Europeans', 9)
# ('apartment', 9)
# ('proceeded', 9)
# ('hurriedly', 9)
# ('exclaimed', 9)
# ('exchanged', 9)
# ('responded', 9)
# ('prisoners', 9)
# ('proceeded', 9)
# ('complaint', 9)
# ('sacrilege', 9)
# ('stupefied', 9)
# ('Certainly', 9)
# ('Whereupon', 9)
# ('imprudent', 9)
# ('confusion', 9)
# ('forgotten', 9)
# ('detective', 9)
# ('advantage', 9)
# ('departure', 9)
# ('consulted', 9)
# ('somewhere', 9)
# ('provinces', 9)
# ('policeman', 9)
# ('detective', 9)
# ('ensconced', 9)
# ('religions', 9)
# ('largeness', 9)
# ('constable', 9)
# ('continued', 9)
# ('stupefied', 9)
# ('composure', 9)
# ('Meanwhile', 9)
# ('liberated', 9)
# ('nourished', 9)
# ('gentleman', 9)
# ('departure', 9)
# ('mast-head', 9)
# ('exclaimed', 9)
# ('necessary', 9)
# ('exhausted', 9)
# ('detective', 9)
# ('recovered', 9)
# ("Company's", 9)
# ('seas--was', 9)
# ('seventeen', 9)
# ('comprised', 9)
# ('occupying', 9)
# ('difficult', 9)
# ('protector', 9)
# ('gratitude', 9)
# ('gentleman', 9)
# ('betraying', 9)
# ('slightest', 9)
# ('regularly', 9)
# ('strictest', 9)
# ('precision', 9)
# ('automaton', 9)
# ('movements', 9)
# ('gratitude', 9)
# ('confirmed', 9)
# ('narrative', 9)
# ('merchants', 9)
# ('protector', 9)
# ('anxieties', 9)
# ('principal', 9)
# ('cannibals', 9)
# ('tree-like', 9)
# ('mountains', 9)
# ('thousands', 9)
# ('luxurious', 9)
# ('Celestial', 9)
# ('landscape', 9)
# ('detective', 9)
# ('unluckily', 9)
# ('forwarded', 9)
# ('difficult', 9)
# ('awakening', 9)
# ('necessity', 9)
# ("steamer's", 9)
# ('Singapore', 9)
# ('necessary', 9)
# ('obstacles', 9)
# ('advantage', 9)
# ('repeating', 9)
# ('necessary', 9)
# ('departure', 9)
# ('departure', 9)
# ('confidant', 9)
# ('doubtless', 9)
# ('detective', 9)
# ('dangerous', 9)
# ('detective', 9)
# ('therefore', 9)
# ('companion', 9)
# ('evidently', 9)
# ('somewhere', 9)
# ('purposely', 9)
# ('elopement', 9)
# ('impressed', 9)
# ('Singapore', 9)
# ('difficult', 9)
# ('following', 9)
# ('Singapore', 9)
# ('detective', 9)
# ('exclaimed', 9)
# ('perplexed', 9)
# ('detective', 9)
# ('thereupon', 9)
# ('recounted', 9)
# ('relatives', 9)
# ('Willingly', 9)
# ('SINGAPORE', 9)
# ('detective', 9)
# ('interview', 9)
# ('companion', 9)
# ('gentleman', 9)
# ('according', 9)
# ('seriously', 9)
# ('certainly', 9)
# ('announced', 9)
# ('following', 9)
# ('cudgelled', 9)
# ('detective', 9)
# ('movements', 9)
# ('ascertain', 9)
# ('gentlemen', 9)
# ('enchanted', 9)
# ('discovery', 9)
# ('allusions', 9)
# ('afternoon', 9)
# ('Wednesday', 9)
# ('separates', 9)
# ('peninsula', 9)
# ('Singapore', 9)
# ('suspected', 9)
# ('perceived', 9)
# ('Singapore', 9)
# ('mountains', 9)
# ('checkered', 9)
# ('brilliant', 9)
# ('half-open', 9)
# ('irregular', 9)
# ('detective', 9)
# ('gourmands', 9)
# ('delicious', 9)
# ('Singapore', 9)
# ('mountains', 9)
# ('inhabited', 9)
# ('Singapore', 9)
# ('principal', 9)
# ('Singapore', 9)
# ('Ceylonese', 9)
# ('intervals', 9)
# ("steamer's", 9)
# ('defective', 9)
# ('necessary', 9)
# ('consigned', 9)
# ('connected', 9)
# ('something', 9)
# ('disturbed', 9)
# ('Frenchman', 9)
# ('detective', 9)
# ('evidently', 9)
# ('expressed', 9)
# ('bantering', 9)
# ('responded', 9)
# ('companion', 9)
# ('persisted', 9)
# ('descended', 9)
# ('evidently', 9)
# ('suspected', 9)
# ('Frenchman', 9)
# ('detective', 9)
# ('sometimes', 9)
# ('undecided', 9)
# ('preserved', 9)
# ('territory', 9)
# ('situation', 9)
# ('Meanwhile', 9)
# ('agitation', 9)
# ('difficult', 9)
# ('calculate', 9)
# ('discovery', 9)
# ('gratitude', 9)
# ('heartless', 9)
# ('sentiment', 9)
# ('perpetual', 9)
# ('observing', 9)
# ('indignant', 9)
# ('exclaimed', 9)
# ('remaining', 9)
# ('impatient', 9)
# ('monstrous', 9)
# ('whistling', 9)
# ('estimated', 9)
# ('annoyance', 9)
# ('programme', 9)
# ('adversity', 9)
# ('obstinate', 9)
# ('obedience', 9)
# ('carefully', 9)
# ('concealed', 9)
# ('questions', 9)
# ('whereupon', 9)
# ('barometer', 9)
# ('intention', 9)
# ('southward', 9)
# ('signalled', 9)
# ('to-morrow', 9)
# ('betraying', 9)
# ('willingly', 9)
# ("steamer's", 9)
# ('yesterday', 9)
# ('departure', 9)
# ('postponed', 9)
# ('to-morrow', 9)
# ('responses', 9)
# ('remounted', 9)
# ('strangely', 9)
# ('repairing', 9)
# ('seriously', 9)
# ('remainder', 9)
# ('Francisco', 9)
# ('announced', 9)
# ('conducted', 9)
# ('palanquin', 9)
# ('personage', 9)
# ('residence', 9)
# ('merchants', 9)
# ('reflected', 9)
# ('responded', 9)
# ('gentleman', 9)
# ('embarrass', 9)
# ('delighted', 9)
# ('important', 9)
# ('excellent', 9)
# ('separated', 9)
# ('hospitals', 9)
# ('cathedral', 9)
# ('antipodes', 9)
# ('Europeans', 9)
# ('Singapore', 9)
# ('supremacy', 9)
# ('parterres', 9)
# ('permitted', 9)
# ('detective', 9)
# ('disturbed', 9)
# ('gentlemen', 9)
# ('perceived', 9)
# ('detective', 9)
# ('certainly', 9)
# ('certainly', 9)
# ('territory', 9)
# ('exclaimed', 9)
# ('completed', 9)
# ('announced', 9)
# ('companion', 9)
# ('decorated', 9)
# ('furnished', 9)
# ('customers', 9)
# ('whereupon', 9)
# ('supported', 9)
# ('stupefied', 9)
# ('creatures', 9)
# ('merchants', 9)
# ('miserable', 9)
# ('attempted', 9)
# ('stringent', 9)
# ('gradually', 9)
# ('Celestial', 9)
# ('suffering', 9)
# ('willingly', 9)
# ('returning', 9)
# ('Frenchman', 9)
# ('attention', 9)
# ('to-morrow', 9)
# ('companion', 9)
# ('gentlemen', 9)
# ('Frenchman', 9)
# ('continued', 9)
# ('gentlemen', 9)
# ('satisfied', 9)
# ('following', 9)
# ('obstacles', 9)
# ('gentlemen', 9)
# ('continued', 9)
# ('interrupt', 9)
# ('detective', 9)
# ('difficult', 9)
# ('detective', 9)
# ('detective', 9)
# ('detective', 9)
# ('displayed', 9)
# ('gentlemen', 9)
# ('September', 9)
# ('committed', 9)
# ('banknotes', 9)
# ('detective', 9)
# ('exhausted', 9)
# ('stammered', 9)
# ('separated', 9)
# ('influence', 9)
# ('departure', 9)
# ('Frenchman', 9)
# ('escorting', 9)
# ('necessary', 9)
# ('purchases', 9)
# ('acquitted', 9)
# ('companion', 9)
# ('programme', 9)
# ('purchases', 9)
# ('protector', 9)
# ('betraying', 9)
# ('contented', 9)
# ('palanquin', 9)
# ('half-past', 9)
# ('palanquin', 9)
# ('observing', 9)
# ('addressed', 9)
# ('passenger', 9)
# ('yesterday', 9)
# ('anxiously', 9)
# ('responded', 9)
# ('yesterday', 9)
# ('detective', 9)
# ('completed', 9)
# ('stupefied', 9)
# ('invisible', 9)
# ('abandoned', 9)
# ('necessary', 9)
# ('unloading', 9)
# ('therefore', 9)
# ('satisfied', 9)
# ('excursion', 9)
# ('Francisco', 9)
# ('evidently', 9)
# ('venturing', 9)
# ('shuffling', 9)
# ('advantage', 9)
# ('northward', 9)
# ('Francisco', 9)
# ('Perfectly', 9)
# ('therefore', 9)
# ('Tankadere', 9)
# ('advantage', 9)
# ('disturbed', 9)
# ("servant's", 9)
# ('consulate', 9)
# ('palanquin', 9)
# ('departure', 9)
# ('Tankadere', 9)
# ('sheathing', 9)
# ('iron-work', 9)
# ('storm-jib', 9)
# ('Tankadere', 9)
# ('sprightly', 9)
# ('energetic', 9)
# ('installed', 9)
# ('detective', 9)
# ('profiting', 9)
# ('direction', 9)
# ('detective', 9)
# ('Frenchman', 9)
# ('influence', 9)
# ('Tankadere', 9)
# ('TANKADERE', 9)
# ('equinoxes', 9)
# ('advantage', 9)
# ('imprudent', 9)
# ('Tankadere', 9)
# ('Tankadere', 9)
# ('conducted', 9)
# ('admirably', 9)
# ('darkening', 9)
# ('necessary', 9)
# ('Francisco', 9)
# ('traversed', 9)
# ('continent', 9)
# ('important', 9)
# ('strangely', 9)
# ('regretted', 9)
# ('ascertain', 9)
# ('carefully', 9)
# ('examining', 9)
# ('Tankadere', 9)
# ('admirably', 9)
# ('descended', 9)
# ('indicated', 9)
# ('Tankadere', 9)
# ('irregular', 9)
# ('sometimes', 9)
# ('clearings', 9)
# ('fortunate', 9)
# ('freshened', 9)
# ('roughness', 9)
# ('palatable', 9)
# ('collaring', 9)
# ('expending', 9)
# ('ensconced', 9)
# ('Meanwhile', 9)
# ('gentleman', 9)
# ('responded', 9)
# ('tightened', 9)
# ('recording', 9)
# ('overtaken', 9)
# ('seriously', 9)
# ('Tankadere', 9)
# ('difficult', 9)
# ('barometer', 9)
# ('announced', 9)
# ('indicated', 9)
# ('muttering', 9)
# ('confirmed', 9)
# ('according', 9)
# ('dispensed', 9)
# ('storm-jib', 9)
# ('requested', 9)
# ('consented', 9)
# ('descended', 9)
# ('Tankadere', 9)
# ('northward', 9)
# ('monstrous', 9)
# ('submerged', 9)
# ('mountains', 9)
# ('submitted', 9)
# ('protector', 9)
# ('weathered', 9)
# ('programme', 9)
# ('Tankadere', 9)
# ('increased', 9)
# ('Well--yes', 9)
# ('Tankadere', 9)
# ('northward', 9)
# ('exhausted', 9)
# ('complaint', 9)
# ('Tankadere', 9)
# ('Tankadere', 9)
# ('descended', 9)
# ('exhausted', 9)
# ('decidedly', 9)
# ('Tankadere', 9)
# ('Tankadere', 9)
# ('evidently', 9)
# ('perfectly', 9)
# ('appointed', 9)
# ('desperate', 9)
# ('Tankadere', 9)
# ('touchhole', 9)
# ('half-mast', 9)
# ('resounded', 9)
# ('ANTIPODES', 9)
# ('half-past', 9)
# ('passenger', 9)
# ('struggled', 9)
# ('influence', 9)
# ('alongside', 9)
# ('evidently', 9)
# ('Frenchman', 9)
# ('difficult', 9)
# ('important', 9)
# ('detective', 9)
# ('detective', 9)
# ('following', 9)
# ('apologise', 9)
# ('behaviour', 9)
# ('proceeded', 9)
# ('resembled', 9)
# ('descended', 9)
# ('passenger', 9)
# ('gentleman', 9)
# ('talkative', 9)
# ('Certainly', 9)
# ('inveigled', 9)
# ('certainly', 9)
# ('situation', 9)
# ('certainly', 9)
# ('important', 9)
# ('residence', 9)
# ('spiritual', 9)
# ('territory', 9)
# ('aimlessly', 9)
# ('Americans', 9)
# ('merchants', 9)
# ('Frenchman', 9)
# ('connected', 9)
# ('inhabited', 9)
# ('necessary', 9)
# ('beautiful', 9)
# ('sheltered', 9)
# ('sectaries', 9)
# ('Confucius', 9)
# ('yellowish', 9)
# ('encrusted', 9)
# ('enveloped', 9)
# ('respected', 9)
# ('civilians', 9)
# ('jet-black', 9)
# ('displayed', 9)
# ('blackened', 9)
# ('jewellery', 9)
# ('ornaments', 9)
# ('streamers', 9)
# ('concocted', 9)
# ('camellias', 9)
# ('expanding', 9)
# ('cultivate', 9)
# ('protected', 9)
# ('voracious', 9)
# ('multitude', 9)
# ('symbolise', 9)
# ('strolling', 9)
# ('odourless', 9)
# ('certainly', 9)
# ('breakfast', 9)
# ('contained', 9)
# ('sacrilege', 9)
# ('preserved', 9)
# ('plentiful', 9)
# ("butcher's", 9)
# ('partridge', 9)
# ('necessary', 9)
# ('following', 9)
# ('executing', 9)
# ('boundings', 9)
# ('fishermen', 9)
# ('succeeded', 9)
# ('departing', 9)
# ('something', 9)
# ('melodious', 9)
# ('therefore', 9)
# ('wandering', 9)
# ('immediate', 9)
# ('accoutred', 9)
# ('one-sided', 9)
# ('Japanesed', 9)
# ('tea-house', 9)
# ('breakfast', 9)
# ('Francisco', 9)
# ('ACROBATIC', 9)
# ('DEPARTURE', 9)
# ('PATRONAGE', 9)
# ('streamers', 9)
# ('represent', 9)
# ('gentleman', 9)
# ('according', 9)
# ('caressing', 9)
# ('bass-viol', 9)
# ('Frenchman', 9)
# ('Frenchmen', 9)
# ('Americans', 9)
# ('recalling', 9)
# ('exercises', 9)
# ('concluded', 9)
# ('something', 9)
# ('dignified', 9)
# ('Francisco', 9)
# ('announced', 9)
# ('deafening', 9)
# ('orchestra', 9)
# ('resounded', 9)
# ('shoulders', 9)
# ('Europeans', 9)
# ('musicians', 9)
# ('acrobatic', 9)
# ('confessed', 9)
# ('performed', 9)
# ('revolving', 9)
# ('stretched', 9)
# ('dispersed', 9)
# ('wonderful', 9)
# ('precision', 9)
# ('principal', 9)
# ('patronage', 9)
# ('shoulders', 9)
# ('imitation', 9)
# ('performed', 9)
# ('gymnastic', 9)
# ('exercises', 9)
# ('sectaries', 9)
# ('represent', 9)
# ('frolicked', 9)
# ('announced', 9)
# ('represent', 9)
# ('shoulders', 9)
# ('performer', 9)
# ('necessary', 9)
# ('something', 9)
# ('stretched', 9)
# ('orchestra', 9)
# ('deafening', 9)
# ('shattered', 9)
# ('banknotes', 9)
# ('half-past', 9)
# ('departure', 9)
# ('Tankadere', 9)
# ('half-mast', 9)
# ('rewarding', 9)
# ('Frenchman', 9)
# ('Francisco', 9)
# ('announced', 9)
# ('necessary', 9)
# ('wandering', 9)
# ('certainly', 9)
# ('eccentric', 9)
# ('perceived', 9)
# ('pell-mell', 9)
# ('recounted', 9)
# ('Tankadere', 9)
# ('detective', 9)
# ('overtaken', 9)
# ('narrative', 9)
# ('furnished', 9)
# ('necessary', 9)
# ('Frenchman', 9)
# ('Francisco', 9)
# ('Steamship', 9)
# ('connected', 9)
# ('therefore', 9)
# ('justified', 9)
# ('Francisco', 9)
# ('Americans', 9)
# ('sustained', 9)
# ('justified', 9)
# ('companion', 9)
# ('gratitude', 9)
# ('impressed', 9)
# ('protector', 9)
# ('impatient', 9)
# ('domestics', 9)
# ('exhausted', 9)
# ('difficult', 9)
# ('fantastic', 9)
# ('countries', 9)
# ('civilised', 9)
# ('Francisco', 9)
# ('Liverpool', 9)
# ('doubtless', 9)
# ('traversed', 9)
# ('eightieth', 9)
# ('antipodes', 9)
# ('exhausted', 9)
# ('fifty-two', 9)
# ('meridians', 9)
# ('Singapore', 9)
# ('Singapore', 9)
# ('deviation', 9)
# ('irregular', 9)
# ('seventeen', 9)
# ('obstacles', 9)
# ('discovery', 9)
# ('obstinate', 9)
# ('regarding', 9)
# ('countries', 9)
# ('hilarious', 9)
# ('meridians', 9)
# ('moonshine', 9)
# ('precisely', 9)
# ('eightieth', 9)
# ('detective', 9)
# ('different', 9)
# ('different', 9)
# ('detective', 9)
# ('consulate', 9)
# ('reflected', 9)
# ('necessary', 9)
# ('evidently', 9)
# ('elephants', 9)
# ('amazement', 9)
# ('concealed', 9)
# ('amusement', 9)
# ('Americans', 9)
# ('detective', 9)
# ('comforted', 9)
# ('condition', 9)
# ('adversary', 9)
# ('time--yes', 9)
# ('interests', 9)
# ('thrashing', 9)
# ('adversary', 9)
# ('convinced', 9)
# ('separated', 9)
# ('hereafter', 9)
# ('obstacles', 9)
# ('ascertain', 9)
# ('convinced', 9)
# ('detective', 9)
# ('detective', 9)
# ('Francisco', 9)
# ('FRANCISCO', 9)
# ('continent', 9)
# ('unloading', 9)
# ('Alongside', 9)
# ('continent', 9)
# ('executing', 9)
# ('proceeded', 9)
# ('therefore', 9)
# ('curiosity', 9)
# ('omnibuses', 9)
# ('Americans', 9)
# ('Europeans', 9)
# ('surprised', 9)
# ('Francisco', 9)
# ('legendary', 9)
# ('assassins', 9)
# ('gold-dust', 9)
# ('seemingly', 9)
# ('Celestial', 9)
# ('Sombreros', 9)
# ('multitude', 9)
# ('nervously', 9)
# ('Francisco', 9)
# ('Boulevard', 9)
# ('breakfast', 9)
# ('consulate', 9)
# ('revolvers', 9)
# ('listening', 9)
# ('consulate', 9)
# ('proceeded', 9)
# ('detective', 9)
# ('gentleman', 9)
# ('delighted', 9)
# ('accompany', 9)
# ('collected', 9)
# ('streamers', 9)
# ('political', 9)
# ('political', 9)
# ('petroleum', 9)
# ('warehouse', 9)
# ('multitude', 9)
# ('disappear', 9)
# ('cries--an', 9)
# ('energetic', 9)
# ('evidently', 9)
# ('champions', 9)
# ('agitation', 9)
# ('offensive', 9)
# ('direction', 9)
# ('exchanged', 9)
# ('carriages', 9)
# ('omnibuses', 9)
# ('revolvers', 9)
# ('evidently', 9)
# ('companion', 9)
# ('shoulders', 9)
# ('exclaimed', 9)
# ('seriously', 9)
# ('resembled', 9)
# ('compactly', 9)
# ('detective', 9)
# ('necessary', 9)
# ('opportune', 9)
# ('revolvers', 9)
# ('perceived', 9)
# ('adventure', 9)
# ('evidently', 9)
# ('detective', 9)
# ('Francisco', 9)
# ('political', 9)
# ('assembled', 9)
# ('Americans', 9)
# ('Francisco', 9)
# ('Francisco', 9)
# ('territory', 9)
# ('Francisco', 9)
# ('southerly', 9)
# ('parallels', 9)
# ('President', 9)
# ('commenced', 9)
# ('execution', 9)
# ('territory', 9)
# ('Mountains', 9)
# ('Mountains', 9)
# ('Mountains', 9)
# ('exceeding', 9)
# ('traversed', 9)
# ('hoped--to', 9)
# ('Liverpool', 9)
# ('direction', 9)
# ('conducted', 9)
# ('platforms', 9)
# ('platforms', 9)
# ('customers', 9)
# ('cheerless', 9)
# ('stoppages', 9)
# ('detective', 9)
# ('relations', 9)
# ('slightest', 9)
# ('announced', 9)
# ('dormitory', 9)
# ('bedsteads', 9)
# ('carefully', 9)
# ('ingenious', 9)
# ('traveller', 9)
# ('protected', 9)
# ('everybody', 9)
# ('Francisco', 9)
# ('Francisco', 9)
# ('direction', 9)
# ('important', 9)
# ('dormitory', 9)
# ('suspended', 9)
# ('mountains', 9)
# ('breakfast', 9)
# ('northward', 9)
# ('landscape', 9)
# ('mountains', 9)
# ('Sometimes', 9)
# ('buffaloes', 9)
# ('thousands', 9)
# ('buffaloes', 9)
# ('deafening', 9)
# ('direction', 9)
# ('spectacle', 9)
# ('platforms', 9)
# ('buffaloes', 9)
# ('discharge', 9)
# ('revolvers', 9)
# ('programme', 9)
# ('buffaloes', 9)
# ('patiently', 9)
# ('buffaloes', 9)
# ('half-past', 9)
# ('UNDERGOES', 9)
# ('direction', 9)
# ('personage', 9)
# ('personage', 9)
# ('moustache', 9)
# ('stockings', 9)
# ('waistcoat', 9)
# ('clergyman', 9)
# ('advantage', 9)
# ('Mormonism', 9)
# ('mysteries', 9)
# ('Mormonism', 9)
# ('contained', 9)
# ('attracted', 9)
# ('ensconced', 9)
# ('appointed', 9)
# ('irritated', 9)
# ('curiously', 9)
# ('naturally', 9)
# ('hardships', 9)
# ('subjected', 9)
# ('succeeded', 9)
# ('subjected', 9)
# ('territory', 9)
# ('rebellion', 9)
# ('disciples', 9)
# ('redoubled', 9)
# ('authority', 9)
# ('published', 9)
# ('centuries', 9)
# ('celestial', 9)
# ('messenger', 9)
# ('narrative', 9)
# ('disciples', 9)
# ('Egyptians', 9)
# ('wearisome', 9)
# ('gradually', 9)
# ('proceeded', 9)
# ('creditors', 9)
# ('disciples', 9)
# ('listening', 9)
# ('community', 9)
# ('numbering', 9)
# ('announced', 9)
# ('candidate', 9)
# ('ambuscade', 9)
# ('disguised', 9)
# ('successor', 9)
# ('emigrants', 9)
# ('practised', 9)
# ('territory', 9)
# ('continued', 9)
# ('half-past', 9)
# ('northwest', 9)
# ('encrusted', 9)
# ('increased', 9)
# ('different', 9)
# ('distilled', 9)
# ('luxuriant', 9)
# ('milk-wort', 9)
# ('powdering', 9)
# ('connected', 9)
# ('expresses', 9)
# ('certainly', 9)
# ("prophet's", 9)
# ('principal', 9)
# ('pavilions', 9)
# ('populated', 9)
# ('traversed', 9)
# ('palisades', 9)
# ('accounted', 9)
# ('according', 9)
# ('creatures', 9)
# ('Some--the', 9)
# ('happiness', 9)
# ('doubtless', 9)
# ('decidedly', 9)
# ('gentleman', 9)
# ('evidently', 9)
# ('exhausted', 9)
# ('anxiously', 9)
# ('recovered', 9)
# ('northward', 9)
# ('completed', 9)
# ('Francisco', 9)
# ('direction', 9)
# ('Mountains', 9)
# ('Mountains', 9)
# ('engineers', 9)
# ('engineers', 9)
# ('violating', 9)
# ('elevation', 9)
# ('described', 9)
# ('necessary', 9)
# ('impatient', 9)
# ('difficult', 9)
# ('accidents', 9)
# ('Territory', 9)
# ('following', 9)
# ('interrupt', 9)
# ('certainly', 9)
# ('Frenchman', 9)
# ('different', 9)
# ('platforms', 9)
# ('Francisco', 9)
# ('discovery', 9)
# ('evidences', 9)
# ('sentiment', 9)
# ('protector', 9)
# ('gratitude', 9)
# ('necessary', 9)
# ('adversary', 9)
# ('collision', 9)
# ('gentlemen', 9)
# ('whispered', 9)
# ('detective', 9)
# ('something', 9)
# ('detaining', 9)
# ('difficult', 9)
# ('gentleman', 9)
# ('naturally', 9)
# ('sedentary', 9)
# ('detective', 9)
# ('difficult', 9)
# ('Certainly', 9)
# ('education', 9)
# ('favourite', 9)
# ('commenced', 9)
# ('detective', 9)
# ('Mountains', 9)
# ('declivity', 9)
# ('Mountains', 9)
# ('irrigated', 9)
# ('southward', 9)
# ('half-past', 9)
# ('Mountains', 9)
# ('difficult', 9)
# ('nakedness', 9)
# ('breakfast', 9)
# ('whistling', 9)
# ('gentleman', 9)
# ('contented', 9)
# ('descended', 9)
# ('conductor', 9)
# ('excitedly', 9)
# ('According', 9)
# ('condition', 9)
# ('condition', 9)
# ('Americans', 9)
# ('immovable', 9)
# ('conductor', 9)
# ('Certainly', 9)
# ('conductor', 9)
# ('conductor', 9)
# ('banknotes', 9)
# ('reckoning', 9)
# ('compelled', 9)
# ('protested', 9)
# ('certainly', 9)
# ('attracted', 9)
# ('attention', 9)
# ('Gentlemen', 9)
# ('passenger', 9)
# ('conductor', 9)
# ('attracted', 9)
# ('delighted', 9)
# ('engineers', 9)
# ('astounded', 9)
# ('dangerous', 9)
# ('passenger', 9)
# ('passenger', 9)
# ('shrugging', 9)
# ('shoulders', 9)
# ('Doubtless', 9)
# ('Frenchman', 9)
# ('conductor', 9)
# ('reversing', 9)
# ('increased', 9)
# ('frightful', 9)
# ('prolonged', 9)
# ('perceived', 9)
# ('INCIDENTS', 9)
# ('RAILROADS', 9)
# ('elevation', 9)
# ('limitless', 9)
# ('southward', 9)
# ('Francisco', 9)
# ('Julesburg', 9)
# ('performed', 9)
# ('imitation', 9)
# ('fireworks', 9)
# ("Amphion's", 9)
# ('McPherson', 9)
# ('traversed', 9)
# ('important', 9)
# ('tributary', 9)
# ('gentleman', 9)
# ('insisting', 9)
# ('attempted', 9)
# ('detective', 9)
# ('endeavour', 9)
# ('adversary', 9)
# ('Francisco', 9)
# ('completed', 9)
# ('exchanged', 9)
# ('returning', 9)
# ('detective', 9)
# ('announced', 9)
# ('revolvers', 9)
# ('conductor', 9)
# ('gentlemen', 9)
# ('gentleman', 9)
# ('conductor', 9)
# ('gentlemen', 9)
# ('conductor', 9)
# ('gentleman', 9)
# ('perfectly', 9)
# ('conductor', 9)
# ('gentleman', 9)
# ('muttering', 9)
# ('conductor', 9)
# ('conductor', 9)
# ('gentlemen', 9)
# ('revolvers', 9)
# ('remaining', 9)
# ('gentlemen', 9)
# ('listening', 9)
# ('resounded', 9)
# ('certainly', 9)
# ('duellists', 9)
# ('continued', 9)
# ('proceeded', 9)
# ('revolvers', 9)
# ('clamorous', 9)
# ('perceived', 9)
# ('according', 9)
# ('responded', 9)
# ('regulator', 9)
# ('thrusting', 9)
# ('sustained', 9)
# ('necessary', 9)
# ('conductor', 9)
# ('preparing', 9)
# ('succeeded', 9)
# ('continued', 9)
# ('acrobatic', 9)
# ('suspended', 9)
# ('succeeded', 9)
# ('increased', 9)
# ('attracted', 9)
# ('Frenchman', 9)
# ('including', 9)
# ('prisoners', 9)
# ('seriously', 9)
# ('attention', 9)
# ('certainly', 9)
# ('prisoners', 9)
# ('Doubtless', 9)
# ('prisoners', 9)
# ('agitation', 9)
# ('composure', 9)
# ('permitted', 9)
# ('greenness', 9)
# ('Decidedly', 9)
# ('detective', 9)
# ('Sometimes', 9)
# ('Footsteps', 9)
# ('afternoon', 9)
# ('appearing', 9)
# ('fantastic', 9)
# ('telegraph', 9)
# ('Francisco', 9)
# ('explained', 9)
# ('deafening', 9)
# ('continued', 9)
# ('slackened', 9)
# ('remaining', 9)
# ('separated', 9)
# ('dangerous', 9)
# ('pillaging', 9)
# ('backwards', 9)
# ('whistling', 9)
# ('conductor', 9)
# ('prisoners', 9)
# ('interrupt', 9)
# ('conductor', 9)
# ('Francisco', 9)
# ('To-morrow', 9)
# ('To-morrow', 9)
# ('responded', 9)
# ('conductor', 9)
# ('influence', 9)
# ('Meanwhile', 9)
# ('detective', 9)
# ('wandering', 9)
# ('commander', 9)
# ('intensely', 9)
# ('detective', 9)
# ('recognise', 9)
# ('southward', 9)
# ('sacrifice', 9)
# ('perceived', 9)
# ('returning', 9)
# ('Frenchman', 9)
# ('certainly', 9)
# ('confessed', 9)
# ('difficult', 9)
# ('struggled', 9)
# ('Meanwhile', 9)
# ('gentleman', 9)
# ('DETECTIVE', 9)
# ('INTERESTS', 9)
# ('desperate', 9)
# ('detective', 9)
# ('Seriously', 9)
# ('seriously', 9)
# ('necessary', 9)
# ('Liverpool', 9)
# ('necessary', 9)
# ('therefore', 9)
# ('extremely', 9)
# ('confident', 9)
# ('transport', 9)
# ('recovered', 9)
# ('delighted', 9)
# ('difficult', 9)
# ('completed', 9)
# ('traversed', 9)
# ('estimated', 9)
# ('important', 9)
# ('described', 9)
# ('obstacles', 9)
# ('lessening', 9)
# ('resounded', 9)
# ('sheltered', 9)
# ('Liverpool', 9)
# ('detective', 9)
# ('sacrifice', 9)
# ('different', 9)
# ('perceived', 9)
# ('whiteness', 9)
# ('Sometimes', 9)
# ('ferocious', 9)
# ('perceived', 9)
# ('landmarks', 9)
# ('stretched', 9)
# ('stiffened', 9)
# ('important', 9)
# ('connected', 9)
# ('confessed', 9)
# ('regretted', 9)
# ('Davenport', 9)
# ('beautiful', 9)
# ('separated', 9)
# ('gentleman', 9)
# ('traversed', 9)
# ('Liverpool', 9)
# ('admirable', 9)
# ('Liverpool', 9)
# ('movements', 9)
# ('obstacles', 9)
# ('incidents', 9)
# ('to-morrow', 9)
# ('ferryboat', 9)
# ('agitation', 9)
# ('Liverpool', 9)
# ("instant's", 9)
# ('proceeded', 9)
# ('departure', 9)
# ('preparing', 9)
# ('admirable', 9)
# ('indicated', 9)
# ('departure', 9)
# ('Henrietta', 9)
# ('forthwith', 9)
# ('presented', 9)
# ('Henrietta', 9)
# ('Liverpool', 9)
# ('Liverpool', 9)
# ('Liverpool', 9)
# ('Henrietta', 9)
# ('situation', 9)
# ('Henrietta', 9)
# ('Tankadere', 9)
# ('half-past', 9)
# ('disembark', 9)
# ('Henrietta', 9)
# ('performed', 9)
# ('abandoned', 9)
# ('Henrietta', 9)
# ('prolonged', 9)
# ('certainly', 9)
# ('Henrietta', 9)
# ('ascertain', 9)
# ('signified', 9)
# ('excessive', 9)
# ('Liverpool', 9)
# ('banknotes', 9)
# ('Henrietta', 9)
# ('directing', 9)
# ('Liverpool', 9)
# ('adventure', 9)
# ('manoeuvre', 9)
# ('Henrietta', 9)
# ('confirmed', 9)
# ('then--for', 9)
# ('machinery', 9)
# ('Henrietta', 9)
# ('Liverpool', 9)
# ('Henrietta', 9)
# ('Henrietta', 9)
# ('delighted', 9)
# ('enchanted', 9)
# ('dexterous', 9)
# ('acrobatic', 9)
# ('gentlemen', 9)
# ('forgotten', 9)
# ('vexations', 9)
# ('sometimes', 9)
# ('Henrietta', 9)
# ('confessed', 9)
# ('Henrietta', 9)
# ('Henrietta', 9)
# ('Liverpool', 9)
# ('plausible', 9)
# ('detective', 9)
# ('seriously', 9)
# ('continued', 9)
# ('dangerous', 9)
# ('barometer', 9)
# ('indicated', 9)
# ('increased', 9)
# ('slackened', 9)
# ('violently', 9)
# ('Henrietta', 9)
# ('Henrietta', 9)
# ('Sometimes', 9)
# ('continued', 9)
# ('unhappily', 9)
# ('rendering', 9)
# ('departure', 9)
# ('Henrietta', 9)
# ('seriously', 9)
# ('well-nigh', 9)
# ('cherished', 9)
# ('comforted', 9)
# ('earnestly', 9)
# ('Liverpool', 9)
# ('imparting', 9)
# ('overheard', 9)
# ('Liverpool', 9)
# ('detective', 9)
# ('shrugging', 9)
# ('shoulders', 9)
# ('resenting', 9)
# ('reflected', 9)
# ('awkwardly', 9)
# ('refrained', 9)
# ('difficult', 9)
# ('exhausted', 9)
# ('Henrietta', 9)
# ('continued', 9)
# ('predicted', 9)
# ('announced', 9)
# ('commanded', 9)
# ('poop-deck', 9)
# ('permitted', 9)
# ('recovered', 9)
# ('Liverpool', 9)
# ('Pickaroon', 9)
# ('continued', 9)
# ('Henrietta', 9)
# ('pronounce', 9)
# ('passenger', 9)
# ('Henrietta', 9)
# ('banknotes', 9)
# ('consigned', 9)
# ('Liverpool', 9)
# ('something', 9)
# ('passenger', 9)
# ('Certainly', 9)
# ('necessary', 9)
# ('Henrietta', 9)
# ('necessary', 9)
# ('Liverpool', 9)
# ('betraying', 9)
# ('readiness', 9)
# ('Liverpool', 9)
# ('Liverpool', 9)
# ('Henrietta', 9)
# ('therefore', 9)
# ('Henrietta', 9)
# ('gentleman', 9)
# ('half-past', 9)
# ('embarking', 9)
# ('Liverpool', 9)
# ('policemen', 9)
# ('explained', 9)
# ('protector', 9)
# ('concealed', 9)
# ('character', 9)
# ('innocence', 9)
# ('satisfied', 9)
# ('continued', 9)
# ('gentleman', 9)
# ('Liverpool', 9)
# ('Liverpool', 9)
# ('contained', 9)
# ('carefully', 9)
# ('advancing', 9)
# ('situation', 9)
# ('Liverpool', 9)
# ('Admitting', 9)
# ('stammered', 9)
# ('detective', 9)
# ('precision', 9)
# ('descended', 9)
# ('necessary', 9)
# ('surprised', 9)
# ('detective', 9)
# ('traversed', 9)
# ('obstacles', 9)
# ('deposited', 9)
# ('sometimes', 9)
# ('desperate', 9)
# ('expedient', 9)
# ('carefully', 9)
# ('concealed', 9)
# ('breakfast', 9)
# ('breakfast', 9)
# ('certainly', 9)
# ('detective', 9)
# ('Liverpool', 9)
# ('delivered', 9)
# ('influence', 9)
# ('influence', 9)
# ('gratitude', 9)
# ('half-past', 9)
# ('necessary', 9)
# ('therefore', 9)
# ('descended', 9)
# ('something', 9)
# ('Sometimes', 9)
# ('arresting', 9)
# ('miserable', 9)
# ('half-past', 9)
# ('fireplace', 9)
# ('existence', 9)
# ('gentleman', 9)
# ('relatives', 9)
# ('relatives', 9)
# ('kinswoman', 9)
# ('trembling', 9)
# ('sincerity', 9)
# ('rectitude', 9)
# ('sweetness', 9)
# ('to-morrow', 9)
# ('to-morrow', 9)
# ('to-morrow', 9)
# ('Edinburgh', 9)
# ('gentleman', 9)
# ('eccentric', 9)
# ('forgotten', 9)
# ('departure', 9)
# ('abandoned', 9)
# ('threshold', 9)
# ('described', 9)
# ('Telegrams', 9)
# ('detective', 9)
# ('increased', 9)
# ('racehorse', 9)
# ('paralytic', 9)
# ('Albemarle', 9)
# ('collected', 9)
# ('multitude', 9)
# ('financial', 9)
# ('Fallentin', 9)
# ('anxiously', 9)
# ('indicated', 9)
# ('Gentlemen', 9)
# ('ourselves', 9)
# ('Liverpool', 9)
# ('gentlemen', 9)
# ('therefore', 9)
# ('Fallentin', 9)
# ('eccentric', 9)
# ('surprised', 9)
# ('nervously', 9)
# ('gentleman', 9)
# ('yesterday', 9)
# ('Albemarle', 9)
# ('to-morrow', 9)
# ('gentlemen', 9)
# ('indicated', 9)
# ('Certainly', 9)
# ('Seventeen', 9)
# ('perfectly', 9)
# ('suspended', 9)
# ('gentlemen', 9)
# ('HAPPINESS', 9)
# ('enchanted', 9)
# ('gentleman', 9)
# ('staggered', 9)
# ('to-morrow', 9)
# ('kidnapped', 9)
# ('carriages', 9)
# ('indicated', 9)
# ('twentieth', 9)
# ('departure', 9)
# ('travelled', 9)
# ('direction', 9)
# ('therefore', 9)
# ('direction', 9)
# ('precisely', 9)
# ('pecuniary', 9)
# ('cherished', 9)
# ('agreeable', 9)
# ('suggested', 9)
# ('carriages', 9)
# ('elephants', 9)
# ('eccentric', 9)
# ('gentleman', 9)
# ('displayed', 9)
# ('qualities', 9)
# ('GUTENBERG', 9)
# ('copyright', 9)
# ('copyright', 9)
# ('royalties', 9)
# ('trademark', 9)
# ('Gutenberg', 9)
# ('trademark', 9)
# ('complying', 9)
# ('away--you', 9)
# ('trademark', 9)
# ('GUTENBERG', 9)
# ('promoting', 9)
# ('Gutenberg', 9)
# ('available', 9)
# ('agreement', 9)
# ('agreement', 9)
# ('obtaining', 9)
# ('agreement', 9)
# ('paragraph', 9)
# ('Gutenberg', 9)
# ('trademark', 9)
# ('agreement', 9)
# ('complying', 9)
# ('agreement', 9)
# ('paragraph', 9)
# ('agreement', 9)
# ('paragraph', 9)
# ('Gutenberg', 9)
# ('copyright', 9)
# ('Gutenberg', 9)
# ('promoting', 9)
# ('agreement', 9)
# ('agreement', 9)
# ('copyright', 9)
# ('Copyright', 9)
# ('countries', 9)
# ('agreement', 9)
# ('copyright', 9)
# ('Gutenberg', 9)
# ('following', 9)
# ('immediate', 9)
# ('Gutenberg', 9)
# ('Gutenberg', 9)
# ('displayed', 9)
# ('performed', 9)
# ('Gutenberg', 9)
# ('copyright', 9)
# ('providing', 9)
# ('Gutenberg', 9)
# ('appearing', 9)
# ('trademark', 9)
# ('copyright', 9)
# ('copyright', 9)
# ('copyright', 9)
# ('beginning', 9)
# ('paragraph', 9)
# ('immediate', 9)
# ('including', 9)
# ('hypertext', 9)
# ('exporting', 9)
# ('obtaining', 9)
# ('alternate', 9)
# ('specified', 9)
# ('paragraph', 9)
# ('paragraph', 9)
# ('providing', 9)
# ('calculate', 9)
# ('trademark', 9)
# ('royalties', 9)
# ('paragraph', 9)
# ('Gutenberg', 9)
# ('following', 9)
# ('Gutenberg', 9)
# ('specified', 9)
# ('donations', 9)
# ('Gutenberg', 9)
# ('possessed', 9)
# ('paragraph', 9)
# ('agreement', 9)
# ('different', 9)
# ('agreement', 9)
# ('Gutenberg', 9)
# ('trademark', 9)
# ('Gutenberg', 9)
# ('employees', 9)
# ('copyright', 9)
# ('proofread', 9)
# ('copyright', 9)
# ('defective', 9)
# ('equipment', 9)
# ('described', 9)
# ('paragraph', 9)
# ('Gutenberg', 9)
# ('trademark', 9)
# ('agreement', 9)
# ('liability', 9)
# ('including', 9)
# ('LIABILITY', 9)
# ('PARAGRAPH', 9)
# ('TRADEMARK', 9)
# ('AGREEMENT', 9)
# ('receiving', 9)
# ('defective', 9)
# ('providing', 9)
# ('defective', 9)
# ('paragraph', 9)
# ('INCLUDING', 9)
# ('exclusion', 9)
# ('agreement', 9)
# ('agreement', 9)
# ('agreement', 9)
# ('permitted', 9)
# ('provision', 9)
# ('agreement', 9)
# ('remaining', 9)
# ('INDEMNITY', 9)
# ('indemnify', 9)
# ('trademark', 9)
# ('providing', 9)
# ('agreement', 9)
# ('promotion', 9)
# ('liability', 9)
# ('including', 9)
# ('following', 9)
# ('additions', 9)
# ('deletions', 9)
# ('computers', 9)
# ('including', 9)
# ('computers', 9)
# ('donations', 9)
# ('financial', 9)
# ('available', 9)
# ('Gutenberg', 9)
# ('permanent', 9)
# ('Gutenberg', 9)
# ('donations', 9)
# ('Gutenberg', 9)
# ('Gutenberg', 9)
# ('organized', 9)
# ('Gutenberg', 9)
# ('permitted', 9)
# ('principal', 9)
# ('Fairbanks', 9)
# ('employees', 9)
# ('scattered', 9)
# ('locations', 9)
# ('Executive', 9)
# ('Donations', 9)
# ('Gutenberg', 9)
# ('donations', 9)
# ('equipment', 9)
# ('including', 9)
# ('equipment', 9)
# ('donations', 9)
# ('important', 9)
# ('committed', 9)
# ('complying', 9)
# ('charities', 9)
# ('donations', 9)
# ('paperwork', 9)
# ('donations', 9)
# ('locations', 9)
# ('DONATIONS', 9)
# ('determine', 9)
# ('accepting', 9)
# ('donations', 9)
# ('donations', 9)
# ('treatment', 9)
# ('donations', 9)
# ('Gutenberg', 9)
# ('addresses', 9)
# ('Donations', 9)
# ('including', 9)
# ('including', 9)
# ('donations', 9)
# ('Professor', 9)
# ('volunteer', 9)
# ('confirmed', 9)
# ('copyright', 9)
# ('including', 9)
# ('donations', 9)
# ('Gutenberg', 9)
# ('subscribe', 9)

# %% [markdown]
#  ## 7) Now iterate over your original list of words, `book_list` and find all the words with more than 14 letters, which do not contain any of these characters: [6]
#
#  `. - \ /`
#  generator to find words with 14 letters and more
#  put these words into a list and get rid of the words containing . - \ /
#  if not (test.find('.')):
#  signs = '.-\/'

# %%
# Put your answer: code and comment here

# %% [markdown]
#  ## 8) Split the book into a list of chapters [6]
#
#   - This should be a list of strings
#   - Hint - split on the word 'Chapter'
#   - Call the list `chapter_list`

# %%
# Answer 8

chapter_list = [word.split('Chapter') for word in book_words]

display(chapter_list)
# Out:
# [['The'],
#  ['Project'],
#  ['Gutenberg'],
#  ['EBook'],
#  ['of'],
#  ['Around'],
#  ['the'],
#  ['World'],
#  ['in'],
#  ['80'],
#  ['Days,'],
#  ['by'],
#  ['Jules'],
#  ['Verne'],
#  ['This'],
#  ['eBook'],
#  ['is'],
#  ['for'],
#  ['the'],
#  ['use'],
#  ['of'],
#  ['anyone'],
#  ['anywhere'],
#  ['at'],
#  ['no'],
#  ['cost'],
#  ['and'],
#  ['with'],
#  ['almost'],
#  ['no'],
#  ['restrictions'],
#  ['whatsoever.'],
#  ['You'],
#  ['may'],
#  ['copy'],
#  ['it,'],
#  ['give'],
#  ['it'],
#  ['away'],
#  ['or'],
#  ['re-use'],
#  ['it'],
#  ['under'],
#  ['the'],
#  ['terms'],
#  ['of'],
#  ['the'],
#  ['Project'],
#  ['Gutenberg'],
#  ['License'],
#  ['included'],
#  ['with'],
#  ['this'],
#  ['eBook'],
#  ['or'],
#  ['online'],
#  ['at'],
#  ['www.gutenberg.net'],
#  ['Title:'],
#  ['Around'],
#  ['the'],
#  ['World'],
#  ['in'],
#  ['80'],
#  ['Days'],
#  ['Author:'],
#  ['Jules'],
#  ['Verne'],
#  ['Release'],
#  ['Date:'],
#  ['May'],
#  ['15,'],
#  ['2008'],
#  ['[EBook'],
#  ['#103]'],
#  ['Last'],
#  ['updated:'],
#  ['February'],
#  ['18,'],
#  ['2012'],
#  ['Last'],
#  ['updated:'],
#  ['May'],
#  ['5,'],
#  ['2012'],
#  ['Language:'],
#  ['English'],
#  ['***'],
#  ['START'],
#  ['OF'],
#  ['THIS'],
#  ['PROJECT'],
#  ['GUTENBERG'],
#  ['EBOOK'],
#  ['AROUND'],
#  ['THE'],
#  ['WORLD'],
#  ['IN'],
#  ['80'],
#  ['DAYS'],
#  ['***'],
#  ['AROUND'],
#  ['THE'],
#  ['WORLD'],
#  ['IN'],
#  ['EIGHTY'],
#  ['DAYS'],
#  ['CONTENTS'],
#  ['CHAPTER'],
#  ['I'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['AND'],
#  ['PASSEPARTOUT'],
#  ['ACCEPT'],
#  ['EACH'],
#  ['OTHER,'],
#  ['THE'],
#  ['ONE'],
#  ['AS'],
#  ['MASTER,'],
#  ['THE'],
#  ['OTHER'],
#  ['AS'],
#  ['MAN'],
#  ['II'],
#  ['IN'],
#  ['WHICH'],
#  ['PASSEPARTOUT'],
#  ['IS'],
#  ['CONVINCED'],
#  ['THAT'],
#  ['HE'],
#  ['HAS'],
#  ['AT'],
#  ['LAST'],
#  ['FOUND'],
#  ['HIS'],
#  ['IDEAL'],
#  ['III'],
#  ['IN'],
#  ['WHICH'],
#  ['A'],
#  ['CONVERSATION'],
#  ['TAKES'],
#  ['PLACE'],
#  ['WHICH'],
#  ['SEEMS'],
#  ['LIKELY'],
#  ['TO'],
#  ['COST'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['DEAR'],
#  ['IV'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['ASTOUNDS'],
#  ['PASSEPARTOUT,'],
#  ['HIS'],
#  ['SERVANT'],
#  ['V'],
#  ['IN'],
#  ['WHICH'],
#  ['A'],
#  ['NEW'],
#  ['SPECIES'],
#  ['OF'],
#  ['FUNDS,'],
#  ['UNKNOWN'],
#  ['TO'],
#  ['THE'],
#  ['MONEYED'],
#  ['MEN,'],
#  ['APPEARS'],
#  ['ON'],
#  ["'CHANGE"],
#  ['VI'],
#  ['IN'],
#  ['WHICH'],
#  ['FIX,'],
#  ['THE'],
#  ['DETECTIVE,'],
#  ['BETRAYS'],
#  ['A'],
#  ['VERY'],
#  ['NATURAL'],
#  ['IMPATIENCE'],
#  ['VII'],
#  ['WHICH'],
#  ['ONCE'],
#  ['MORE'],
#  ['DEMONSTRATES'],
#  ['THE'],
#  ['USELESSNESS'],
#  ['OF'],
#  ['PASSPORTS'],
#  ['AS'],
#  ['AIDS'],
#  ['TO'],
#  ['dETECTIVES'],
#  ['VIII'],
#  ['IN'],
#  ['WHICH'],
#  ['PASSEPARTOUT'],
#  ['TALKS'],
#  ['RATHER'],
#  ['MORE,'],
#  ['PERHAPS,'],
#  ['THAN'],
#  ['IS'],
#  ['PRUDENT'],
#  ['IX'],
#  ['IN'],
#  ['WHICH'],
#  ['THE'],
#  ['RED'],
#  ['SEA'],
#  ['AND'],
#  ['THE'],
#  ['INDIAN'],
#  ['OCEAN'],
#  ['PROVE'],
#  ['PROPITIOUS'],
#  ['TO'],
#  ['THE'],
#  ['DESIGNS'],
#  ['OF'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['X'],
#  ['IN'],
#  ['WHICH'],
#  ['PASSEPARTOUT'],
#  ['IS'],
#  ['ONLY'],
#  ['TOO'],
#  ['GLAD'],
#  ['TO'],
#  ['GET'],
#  ['OFF'],
#  ['WITH'],
#  ['THE'],
#  ['LOSS'],
#  ['OF'],
#  ['HIS'],
#  ['SHOES'],
#  ['XI'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['SECURES'],
#  ['A'],
#  ['CURIOUS'],
#  ['MEANS'],
#  ['OF'],
#  ['CONVEYANCE'],
#  ['AT'],
#  ['A'],
#  ['FABULOUS'],
#  ['PRICE'],
#  ['XII'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['AND'],
#  ['HIS'],
#  ['COMPANIONS'],
#  ['VENTURE'],
#  ['ACROSS'],
#  ['THE'],
#  ['INDIAN'],
#  ['FORESTS,'],
#  ['AND'],
#  ['WHAT'],
#  ['ENSUED'],
#  ['XIII'],
#  ['IN'],
#  ['WHICH'],
#  ['PASSEPARTOUT'],
#  ['RECEIVES'],
#  ['A'],
#  ['NEW'],
#  ['PROOF'],
#  ['THAT'],
#  ['FORTUNE'],
#  ['FAVORS'],
#  ['THE'],
#  ['BRAVE'],
#  ['XIV'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['DESCENDS'],
#  ['THE'],
#  ['WHOLE'],
#  ['LENGTH'],
#  ['OF'],
#  ['THE'],
#  ['BEAUTIFUL'],
#  ['VALLEY'],
#  ['OF'],
#  ['THE'],
#  ['GANGES'],
#  ['WITHOUT'],
#  ['EVER'],
#  ['THINKING'],
#  ['OF'],
#  ['SEEING'],
#  ['IT'],
#  ['XV'],
#  ['IN'],
#  ['WHICH'],
#  ['THE'],
#  ['BAG'],
#  ['OF'],
#  ['BANKNOTES'],
#  ['DISGORGES'],
#  ['SOME'],
#  ['THOUSANDS'],
#  ['OF'],
#  ['POUNDS'],
#  ['MORE'],
#  ['XVI'],
#  ['IN'],
#  ['WHICH'],
#  ['FIX'],
#  ['DOES'],
#  ['NOT'],
#  ['SEEM'],
#  ['TO'],
#  ['UNDERSTAND'],
#  ['IN'],
#  ['THE'],
#  ['LEAST'],
#  ['WHAT'],
#  ['IS'],
#  ['SAID'],
#  ['TO'],
#  ['HIM'],
#  ['XVII'],
#  ['SHOWING'],
#  ['WHAT'],
#  ['HAPPENED'],
#  ['ON'],
#  ['THE'],
#  ['VOYAGE'],
#  ['FROM'],
#  ['SINGAPORE'],
#  ['TO'],
#  ['HONG'],
#  ['KONG'],
#  ['XVIII'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG,'],
#  ['PASSEPARTOUT,'],
#  ['AND'],
#  ['FIX'],
#  ['GO'],
#  ['EACH'],
#  ['ABOUT'],
#  ['HIS'],
#  ['BUSINESS'],
#  ['XIX'],
#  ['IN'],
#  ['WHICH'],
#  ['PASSEPARTOUT'],
#  ['TAKES'],
#  ['A'],
#  ['TOO'],
#  ['GREAT'],
#  ['INTEREST'],
#  ['IN'],
#  ['HIS'],
#  ['MASTER,'],
#  ['AND'],
#  ['WHAT'],
#  ['COMES'],
#  ['OF'],
#  ['IT'],
#  ['XX'],
#  ['IN'],
#  ['WHICH'],
#  ['FIX'],
#  ['COMES'],
#  ['FACE'],
#  ['TO'],
#  ['FACE'],
#  ['WITH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['XXI'],
#  ['IN'],
#  ['WHICH'],
#  ['THE'],
#  ['MASTER'],
#  ['OF'],
#  ['THE'],
#  ['"TANKADERE"'],
#  ['RUNS'],
#  ['GREAT'],
#  ['RISK'],
#  ['OF'],
#  ['LOSING'],
#  ['A'],
#  ['REWARD'],
#  ['OF'],
#  ['TWO'],
#  ['HUNDRED'],
#  ['POUNDS'],
#  ['XXII'],
#  ['IN'],
#  ['WHICH'],
#  ['PASSEPARTOUT'],
#  ['FINDS'],
#  ['OUT'],
#  ['THAT,'],
#  ['EVEN'],
#  ['AT'],
#  ['THE'],
#  ['ANTIPODES,'],
#  ['IT'],
#  ['IS'],
#  ['CONVENIENT'],
#  ['TO'],
#  ['HAVE'],
#  ['SOME'],
#  ['MONEY'],
#  ['IN'],
#  ["ONE'S"],
#  ['POCKET'],
#  ['XXIII'],
#  ['IN'],
#  ['WHICH'],
#  ["PASSEPARTOUT'S"],
#  ['NOSE'],
#  ['BECOMES'],
#  ['OUTRAGEOUSLY'],
#  ['LONG'],
#  ['XXIV'],
#  ['DURING'],
#  ['WHICH'],
#  ['MR.'],
#  ['FOGG'],
#  ['AND'],
#  ['PARTY'],
#  ['CROSS'],
#  ['THE'],
#  ['PACIFIC'],
#  ['OCEAN'],
#  ['XXV'],
#  ['IN'],
#  ['WHICH'],
#  ['A'],
#  ['SLIGHT'],
#  ['GLIMPSE'],
#  ['IS'],
#  ['HAD'],
#  ['OF'],
#  ['SAN'],
#  ['FRANCISCO'],
#  ['XXVI'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['AND'],
#  ['PARTY'],
#  ['TRAVEL'],
#  ['BY'],
#  ['THE'],
#  ['PACIFIC'],
#  ['RAILROAD'],
#  ['XXVII'],
#  ['IN'],
#  ['WHICH'],
#  ['PASSEPARTOUT'],
#  ['UNDERGOES,'],
#  ['AT'],
#  ['A'],
#  ['SPEED'],
#  ['OF'],
#  ['TWENTY'],
#  ['MILES'],
#  ['AN'],
#  ['HOUR,'],
#  ['A'],
#  ['COURSE'],
#  ['OF'],
#  ['MORMON'],
#  ['HISTORY'],
#  ['XXVIII'],
#  ['IN'],
#  ['WHICH'],
#  ['PASSEPARTOUT'],
#  ['DOES'],
#  ['NOT'],
#  ['SUCCEED'],
#  ['IN'],
#  ['MAKING'],
#  ['ANYBODY'],
#  ['LISTEN'],
#  ['TO'],
#  ['REASON'],
#  ['XXIX'],
#  ['IN'],
#  ['WHICH'],
#  ['CERTAIN'],
#  ['INCIDENTS'],
#  ['ARE'],
#  ['NARRATED'],
#  ['WHICH'],
#  ['ARE'],
#  ['ONLY'],
#  ['TO'],
#  ['BE'],
#  ['MET'],
#  ['WITH'],
#  ['ON'],
#  ['AMERICAN'],
#  ['RAILROADS'],
#  ['XXX'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['SIMPLY'],
#  ['DOES'],
#  ['HIS'],
#  ['DUTY'],
#  ['XXXI'],
#  ['IN'],
#  ['WHICH'],
#  ['FIX,'],
#  ['THE'],
#  ['DETECTIVE,'],
#  ['CONSIDERABLY'],
#  ['FURTHERS'],
#  ['THE'],
#  ['INTERESTS'],
#  ['OF'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['XXXII'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['ENGAGES'],
#  ['IN'],
#  ['A'],
#  ['DIRECT'],
#  ['STRUGGLE'],
#  ['WITH'],
#  ['BAD'],
#  ['FORTUNE'],
#  ['XXXIII'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['SHOWS'],
#  ['HIMSELF'],
#  ['EQUAL'],
#  ['TO'],
#  ['THE'],
#  ['OCCASION'],
#  ['XXXIV'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['AT'],
#  ['LAST'],
#  ['REACHES'],
#  ['LONDON'],
#  ['XXXV'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['DOES'],
#  ['NOT'],
#  ['HAVE'],
#  ['TO'],
#  ['REPEAT'],
#  ['HIS'],
#  ['ORDERS'],
#  ['TO'],
#  ['PASSEPARTOUT'],
#  ['TWICE'],
#  ['XXXVI'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ["FOGG'S"],
#  ['NAME'],
#  ['IS'],
#  ['ONCE'],
#  ['MORE'],
#  ['AT'],
#  ['A'],
#  ['PREMIUM'],
#  ['ON'],
#  ["'CHANGE"],
#  ['XXXVII'],
#  ['IN'],
#  ['WHICH'],
#  ['IT'],
#  ['IS'],
#  ['SHOWN'],
#  ['THAT'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['GAINED'],
#  ['NOTHING'],
#  ['BY'],
#  ['HIS'],
#  ['TOUR'],
#  ['AROUND'],
#  ['THE'],
#  ['WORLD,'],
#  ['UNLESS'],
#  ['IT'],
#  ['WERE'],
#  ['HAPPINESS'],
#  ['', ''],
#  ['I'],
#  ['IN'],
#  ['WHICH'],
#  ['PHILEAS'],
#  ['FOGG'],
#  ['AND'],
#  ['PASSEPARTOUT'],
#  ['ACCEPT'],
#  ['EACH'],
#  ['OTHER,'],
#  ['THE'],
#  ['ONE'],
#  ['AS'],
#  ['MASTER,'],
#  ['THE'],
#  ['OTHER'],
#  ['AS'],
#  ['MAN'],
#  ['Mr.'],
#  ['Phileas'],
#  ['Fogg'],
#  ['lived,'],
#  ['in'],
#  ['1872,'],
#  ['at'],
#  ['No.'],
#  ['7,'],
#  ['Saville'],
#  ['Row,'],
#  ['Burlington'],
#  ['Gardens,'],
#  ['the'],
#  ['house'],
#  ['in'],
#  ['which'],
#  ['Sheridan'],
#  ['died'],
#  ['in'],
#  ['1814.'],
#  ['He'],
#  ['was'],
#  ['one'],
#  ['of'],
#  ['the'],
#  ['most'],
#  ['noticeable'],
#  ['members'],
#  ['of'],
#  ['the'],
#  ['Reform'],
#  ['Club,'],
#  ['though'],
#  ['he'],
#  ['seemed'],
#  ['always'],
#  ['to'],
#  ['avoid'],
#  ['attracting'],
#  ['attention;'],
#  ['an'],
#  ['enigmatical'],
#  ['personage,'],
#  ['about'],
#  ['whom'],
#  ['little'],
#  ['was'],
#  ['known,'],
#  ['except'],
#  ['that'],
#  ['he'],
#  ['was'],
#  ['a'],
#  ['polished'],
#  ['man'],
#  ['of'],
#  ['the'],
#  ['world.'],
#  ['People'],
#  ['said'],
#  ['that'],
#  ['he'],
#  ['resembled'],
#  ['Byron--at'],
#  ['least'],
#  ['that'],
#  ['his'],
#  ['head'],
#  ['was'],
#  ['Byronic;'],
#  ['but'],
#  ['he'],
#  ['was'],
#  ['a'],
#  ['bearded,'],
#  ['tranquil'],
#  ['Byron,'],
#  ['who'],
#  ['might'],
#  ['live'],
#  ['on'],
#  ['a'],
#  ['thousand'],
#  ['years'],
#  ['without'],
#  ['growing'],
#  ['old.'],
#  ['Certainly'],
#  ['an'],
#  ['Englishman,'],
#  ['it'],
#  ['was'],
#  ['more'],
#  ['doubtful'],
#  ['whether'],
#  ['Phileas'],
#  ['Fogg'],
#  ['was'],
#  ['a'],
#  ['Londoner.'],
#  ['He'],
#  ['was'],
#  ['never'],
#  ['seen'],
#  ['on'],
#  ["'Change,"],
#  ['nor'],
#  ['at'],
#  ['the'],
#  ['Bank,'],
#  ['nor'],
#  ['in'],
#  ['the'],
#  ['counting-rooms'],
#  ['of'],
#  ['the'],
#  ['"City";'],
#  ['no'],
#  ['ships'],
#  ['ever'],
#  ['came'],
#  ['into'],
#  ['London'],
#  ['docks'],
#  ['of'],
#  ['which'],
#  ['he'],
#  ['was'],
#  ['the'],
#  ['owner;'],
#  ['he'],
#  ['had'],
#  ['no'],
#  ['public'],
#  ['employment;'],
#  ['he'],
#  ['had'],
#  ['never'],
#  ['been'],
#  ['entered'],
#  ['at'],
#  ['any'],
#  ['of'],
#  ['the'],
#  ['Inns'],
#  ['of'],
#  ['Court,'],
#  ['either'],
#  ['at'],
#  ['the'],
#  ['Temple,'],
#  ['or'],
#  ["Lincoln's"],
#  ['Inn,'],
#  ['or'],
#  ["Gray's"],
#  ['Inn;'],
#  ['nor'],
#  ['had'],
#  ['his'],
#  ['voice'],
#  ['ever'],
#  ['resounded'],
#  ['in'],
#  ['the'],
#  ['Court'],
#  ['of'],
#  ['Chancery,'],
#  ['or'],
#  ['in'],
#  ['the'],
#  ['Exchequer,'],
#  ['or'],
#  ['the'],
#  ["Queen's"],
#  ['Bench,'],
#  ['or'],
#  ['the'],
#  ['Ecclesiastical'],
#  ['Courts.'],
#  ['He'],
#  ['certainly'],
#  ['was'],
#  ['not'],
#  ['a'],
#  ['manufacturer;'],
#  ['nor'],
#  ['was'],
#  ['he'],
#  ['a'],
#  ['merchant'],
#  ['or'],
#  ['a'],
#  ['gentleman'],
#  ['farmer.'],
#  ['His'],
#  ['name'],
#  ['was'],
#  ['strange'],
#  ['to'],
#  ['the'],
#  ['scientific'],
#  ['and'],
#  ['learned'],
#  ['societies,'],
#  ['and'],
#  ['he'],
#  ['never'],
#  ['was'],
#  ['known'],
#  ['to'],
#  ['take'],
#  ['part'],
#  ['in'],
#  ['the'],
#  ['sage'],
#  ['deliberations'],
#  ['of'],
#  ['the'],
#  ['Royal'],
#  ['Institution'],
#  ['or'],
#  ['the'],
#  ['London'],
#  ['Institution,'],
#  ['the'],
#  ["Artisan's"],
#  ['Association,'],
#  ['or'],
#  ['the'],
#  ['Institution'],
#  ['of'],
#  ['Arts'],
#  ['and'],
#  ['Sciences.'],
#  ['He'],
#  ['belonged,'],
#  ['in'],
#  ['fact,'],
#  ['to'],
#  ['none'],
#  ['of'],
#  ['the'],
#  ['numerous'],
#  ['societies'],
#  ['which'],
#  ['swarm'],
#  ['in'],
#  ['the'],
#  ['English'],
#  ['capital,'],
#  ['from'],
#  ['the'],
#  ['Harmonic'],
#  ['to'],
#  ['that'],
#  ['of'],
#  ['the'],
#  ['Entomologists,'],
#  ['founded'],
#  ['mainly'],
#  ['for'],
#  ['the'],
#  ['purpose'],
#  ['of'],
#  ['abolishing'],
#  ['pernicious'],
#  ['insects.'],
#  ['Phileas'],
#  ['Fogg'],
#  ['was'],
#  ['a'],
#  ['member'],
#  ['of'],
#  ['the'],
#  ['Reform,'],
#  ['and'],
#  ['that'],
#  ['was'],
#  ['all.'],
#  ['The'],
#  ['way'],
#  ['in'],
#  ['which'],
#  ['he'],
#  ['got'],
#  ['admission'],
#  ['to'],
#  ['this'],
#  ['exclusive'],
#  ['club'],
#  ['was'],
#  ['simple'],
#  ['enough.'],
#  ['He'],
#  ['was'],
#  ['recommended'],
#  ['by'],
#  ['the'],
#  ['Barings,'],
#  ['with'],
#  ['whom'],
#  ['he'],
#  ['had'],
#  ['an'],
#  ['open'],
#  ['credit.'],
#  ['His'],
#  ['cheques'],
#  ['were'],
#  ['regularly'],
#  ['paid'],
#  ['at'],
#  ['sight'],
#  ['from'],
#  ['his'],
#  ['account'],
#  ['current,'],
#  ['which'],
#  ['was'],
#  ['always'],
#  ['flush.'],
#  ['Was'],
#  ['Phileas'],
#  ['Fogg'],
#  ['rich?'],
#  ['Undoubtedly.'],
#  ['But'],
#  ['those'],
#  ['who'],
#  ['knew'],
#  ['him'],
#  ['best'],
#  ['could'],
#  ['not'],
#  ['imagine'],
#  ['how'],
#  ['he'],
#  ['had'],
#  ['made'],
#  ['his'],
#  ['fortune,'],
#  ['and'],
#  ['Mr.'],
#  ['Fogg'],
#  ...]

# %% [markdown]
#  ## 9) Remove the first entry from the chapter list [6]
#  The first item in the chapter list is just the preface and chapter list. Copy that into a separate string variable and then remove it from the chapter list

# %%
# Put your answer: code and comment here

# %% [markdown]
#  ## 10) Now take each chapter and split it into a list of words, producing a list of lists - one for each chapter [6]

# %%
# Put your answer: code and comment here

# %% [markdown]
#  ## 11) Print only the titles from each chapter [6]
#  - Clue: The title of each chapter is written in UPPER CASE and is the first thing in each chapter. Therefore, printing words until you find one that is not upper case will print the title.

# %%
# Put your answer: code and comment here

# %% [markdown]
#  ## 12) Measure the length of each chapter and plot the values on a bar chart [9]
#  - Draw a horizontal bar chart so you can read the chapter numbers down the left side
#  - Set the headings to be `Chapter I` to `Chapter XXXVI` do this with code that extracts the chapter headings from the text, not by hand
#  - Give the chart appropriate title and axis labels
#  - Use whatever plotting library you like. Matplotlib is fine.

# %%
# Put your answer: code and comment here

# %% [markdown]
#  ## 13) Plot Locations Mentioned in the Book on a Map [9]
#
#  - Using a plotting package of your choice, plot the locations of all the cities mentioned in the book
#  - You can use the file called `cities.txt` to look up city names and locations
#  - Look at its contents to work out how to use it. The locations are given as latitude, longitude, altitude (you won't need that last one!)
#  - You should then write code that searches the book for all the cities in `cities.txt`. Any that it finds should be plotted on the map
#  - Here is a useful list of words that appear in the book, but are NOT to be plotted:
#
#  `['Victoria','San','Imperial','Come','San Pablo','Queenstown','Young','Lincoln','Forster','Formosa']`

# %%
# Put your answer: code and comment here

# %% [markdown]
#  ## 14) NLTK Sentiment Analysis [9]
#
#  ## Use the VADER tool in the nltk library to analyse the sentiment of each chapter and plot the positive sentiment level over time on a chart

# %%
# Put your answer: code and comment here

# %% [markdown]
#  ## 15) Now think of some further analysis you could do based on the text of this book [19]
#
#  It should use other data sources you find online and tell an additional story around the data. Suggested data and sources include:
#
#  - Travel and accommodation sites
#  - User reviews of the book
#  - Book sales data about this and other related books
#  - News stories about places in the book
#  - Travel times and distances
#  - Pictures of places in the book
#
#  Your analysis might consider how Phileas Fogg would travel if he had to make the same journey today - what would it cost, where might he stay, what would be happening in the places he would visit? How would you aquire the data you need? Can you connect to data online using REST? Do you need to perform scraping with something like ScraPy? What other packages would you need and what would you use them for?
#
#  Write in English (not Python) about your idea including data sources, Python packages used, presentation and visualisation methods, and potential problems you can forsee.
#
#  Add some example of code that perform some of the tasks required for your full analysis. You do not have to implement the whole idea, just some illustrative parts.
#
#  Use as many cells below as you need - both code and markdown to explain your ideas. This part is worth 19 of the marks overall.
